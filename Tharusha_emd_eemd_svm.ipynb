# %% [markdown]
# <a href="https://colab.research.google.com/github/Tharusha-Sihan/BSP-Paper-Implementation/blob/main/Tharusha_emd_eemd_svm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wfdb
# !pip install EMD-signal
# !pip install antropy

from google.colab import drive
drive.mount('/content/drive')

# !ls '/content/drive/MyDrive/Colab Notebooks/BSP_Paper_Implementation/mit-bih-arrhythmia-database-1.0.0'
# Out:
# Requirement already satisfied: wfdb in /usr/local/lib/python3.10/dist-packages (4.1.2)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb) (3.7.1)
# Requirement already satisfied: numpy>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.26.4)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (2.2.2)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from wfdb) (2.32.3)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->wfdb) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->wfdb) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (2024.8.30)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.16.0)
# Requirement already satisfied: EMD-signal in /usr/local/lib/python3.10/dist-packages (1.6.4)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.10/dist-packages (from EMD-signal) (1.26.4)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.10/dist-packages (from EMD-signal) (1.13.1)
# Requirement already satisfied: pathos>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from EMD-signal) (0.3.3)
# Requirement already satisfied: tqdm<5.0,>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from EMD-signal) (4.66.5)
# Requirement already satisfied: ppft>=1.7.6.9 in /usr/local/lib/python3.10/dist-packages (from pathos>=0.2.1->EMD-signal) (1.7.6.9)
# Requirement already satisfied: dill>=0.3.9 in /usr/local/lib/python3.10/dist-packages (from pathos>=0.2.1->EMD-signal) (0.3.9)
# Requirement already satisfied: pox>=0.3.5 in /usr/local/lib/python3.10/dist-packages (from pathos>=0.2.1->EMD-signal) (0.3.5)
# Requirement already satisfied: multiprocess>=0.70.17 in /usr/local/lib/python3.10/dist-packages (from pathos>=0.2.1->EMD-signal) (0.70.17)
# Requirement already satisfied: antropy in /usr/local/lib/python3.10/dist-packages (0.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from antropy) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from antropy) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from antropy) (1.5.2)
# Requirement already satisfied: numba>=0.57 in /usr/local/lib/python3.10/dist-packages (from antropy) (0.60.0)
# Requirement already satisfied: stochastic in /usr/local/lib/python3.10/dist-packages (from antropy) (0.7.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.57->antropy) (0.43.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->antropy) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->antropy) (3.5.0)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 100.atr    105.atr  111.atr  116.dat  122.atr  202.dat	209.at_  214.xws  221.xws  231.xws
# 100.dat    105.dat  111.dat  116.hea  122.dat  202.hea	209.atr  215.at_  222.at_  232.atr
# 100.hea    105.hea  111.hea  116.xws  122.hea  202.xws	209.dat  215.atr  222.atr  232.dat
# 100.xws    105.xws  111.xws  117.at_  122.xws  203.at-	209.hea  215.dat  222.dat  232.hea
# 101.atr    106.atr  112.atr  117.atr  123.atr  203.at_	209.xws  215.hea  222.hea  232.xws
# 101.dat    106.dat  112.dat  117.dat  123.dat  203.atr	210.atr  215.xws  222.xws  233.atr
# 101.hea    106.hea  112.hea  117.hea  123.hea  203.dat	210.dat  217.atr  223.atr  233.dat
# 101.xws    106.xws  112.xws  117.xws  123.xws  203.hea	210.hea  217.dat  223.dat  233.hea
# 102-0.atr  107.atr  113.atr  118.atr  124.atr  203.xws	210.xws  217.hea  223.hea  233.xws
# 102.atr    107.dat  113.dat  118.dat  124.dat  205.atr	212.atr  217.xws  223.xws  234.atr
# 102.dat    107.hea  113.hea  118.hea  124.hea  205.dat	212.dat  219.atr  228.atr  234.dat
# 102.hea    107.xws  113.xws  118.xws  124.xws  205.hea	212.hea  219.dat  228.dat  234.hea
# 102.xws    108.at_  114.atr  119.at_  200.atr  205.xws	212.xws  219.hea  228.hea  234.xws
# 103.atr    108.atr  114.dat  119.atr  200.dat  207.atr	213.atr  219.xws  228.xws  ANNOTATORS
# 103.dat    108.dat  114.hea  119.dat  200.hea  207.dat	213.dat  220.atr  230.atr  mitdbdir
# 103.hea    108.hea  114.xws  119.hea  200.xws  207.hea	213.hea  220.dat  230.dat  RECORDS
# 103.xws    108.xws  115.atr  119.xws  201.atr  207.xws	213.xws  220.hea  230.hea  SHA256SUMS.txt
# 104.atr    109.atr  115.dat  121.atr  201.dat  208.atr	214.at_  220.xws  230.xws  x_mitdb
# 104.dat    109.dat  115.hea  121.dat  201.hea  208.dat	214.atr  221.atr  231.atr
# 104.hea    109.hea  115.xws  121.hea  201.xws  208.hea	214.dat  221.dat  231.dat
# 104.xws    109.xws  116.atr  121.xws  202.atr  208.xws	214.hea  221.hea  231.hea

# %%
import os
import wfdb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.signal as sg
import antropy as ant

from numpy.linalg import svd
from scipy import stats
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split
from PyEMD import EMD, EEMD
# from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor

# Define the path to the dataset directory in your Google Drive
path = '/content/drive/MyDrive/Colab Notebooks/BSP_Paper_Implementation/mit-bih-arrhythmia-database-1.0.0/'

# %%
# Define parameters

SEGMENT_SIZE = 300
TRAIN_SET_SIZE = 2000
TEST_SET_SIZE = 500

# EMD and EEMD parameters
EMD_IMFS = 3
EEMD_IMFS = 7

# %%
#### Function definitions

## Preprocessing

# Mean bias correction
def bias_correction(signal):
    return signal - np.mean(signal)

# Moving average filter
def MA_filter(signal, window_size=6):
    return np.convolve(signal, np.ones(window_size)/window_size, mode='valid')

# High pass filter
def HP_filter(signal, cutoff=1, fs=360, order=6):
    nyquist = 0.5 * fs  # Nyquist frequency
    normal_cutoff = cutoff / nyquist  # Normalize the cutoff frequency
    b, a = sg.butter(order, normal_cutoff, btype='high', analog=False)  # Butterworth filter
    filtered_signal = sg.filtfilt(b, a, signal)  # Apply filter
    return filtered_signal

# Low pass filter
def LP_filter(signal, cutoff=45, fs=360, order=5):
    nyquist = 0.5 * fs  # Nyquist frequency
    normal_cutoff = cutoff / nyquist  # Normalize the cutoff frequency
    b, a = sg.butter(order, normal_cutoff, btype='low', analog=False)  # Butterworth filter
    filtered_signal = sg.filtfilt(b, a, signal)  # forward backward filtering
    return filtered_signal

# Denoising
def denoise(signal):
    stage1 = bias_correction(signal)
    stage2 = MA_filter(stage1)
    stage3 = HP_filter(stage2)
    stage4 = LP_filter(stage3)
    return stage4

## Feature extraction

# Initializing EMD
emd = EMD(spline_kind = "cubic", std_thr = 0.3, total_power_thr = 0.0005, range_thr = 0.0001)

# Initializing EEMD
eemd = EEMD()

# Extracting the feature vector from a set of IMFs
def extract_features(IMFs):
    # Combine all features into a feature vector
    feature_vector = []
    column_names = []
    i = 0
    for imf in IMFs:
        i = i + 1
        # Calculate Sample Entropy
        sampEn = ant.sample_entropy(imf)

        # Calculate Coefficient of Variation (CV)
        mean_imf = np.mean(imf)
        std_imf = np.std(imf)
        CV = (std_imf / mean_imf) ** 2

        # Perform SVD and extract singular value
        singular_value = svd(imf.reshape(-1, 1), compute_uv=False)[0]

        # Calculate Band Power
        bp_value = np.mean(np.square(imf))

        features = [sampEn, CV, singular_value, bp_value]
        columns = [f'SE {i}', f'CV {i}', f'SV {i}', f'BP {i}']
        feature_vector = np.concatenate((feature_vector, features))
        column_names = np.concatenate((column_names, columns))
    column_names = np.concatenate((column_names, ["Class"]))
    return feature_vector, column_names

# Extracting features data fram from an input dataframe
def get_features_df(input_df, decompose):
    print("Started extracting features")
    all_features_df = pd.DataFrame()
    # print(all_features_df.shape)
    for i in range(input_df.shape[0]):
        X_i = input_df.iloc[i, :-1].to_numpy()
        y_i = input_df.iloc[i,-1]

        if (decompose == "eemd"):
            IMFs = eemd (X_i, max_imf = EEMD_IMFS)
            if (len(IMFs)>EEMD_IMFS):
                IMFs = IMFs[0:EEMD_IMFS]

        elif (decompose == "emd"):
            IMFs = emd(X_i, max_imf = EMD_IMFS)
            if (len(IMFs)>EMD_IMFS):
                IMFs = IMFs[0:EMD_IMFS]

        else:
            print(f"Error: Invalid decomposition method '{decompose}' provided")
            break
        print(f"Decomposed segment {i+1}", end='; ')

        features_i, column_names = extract_features(IMFs)
        print(f"Extracted features from segment {i+1}", end='; ')
        features_i = np.append(features_i, y_i)
        feature_df = pd.DataFrame([features_i], columns=column_names)
        print(f"Created a dataframe for segment {i+1}.")
        all_features_df = pd.concat([all_features_df, feature_df], ignore_index=True)

    print("Finished extracting features")
    print() # Print an empty space
    return all_features_df

# %%
# Segment size
window_size = SEGMENT_SIZE

# Define arrhythmia classes
classes = ['N', 'L', 'R', 'A', 'V']  # Normal, Left Bundle Branch Block (LBBB), Right Bundle Branch Block (RBBB), Atrial Premature (AP), Ventricular Premature (VP)
n_classes = len(classes)
count_classes = [0] * n_classes

# Initialize lists to store beats and labels
X = list()
y = list()

# Fetch record files from the dataset directory
filenames = next(os.walk(path))[2]
filenames.sort()

# Process each record and annotation
for filename in filenames:
    example_beat_printed = False
    # Only process .dat files (the signal data files)
    if filename.endswith('.dat'):
        record_name = filename.split('.')[0]

        # Read the record (signals) and annotations
        record = wfdb.rdrecord(path + record_name)
        annotation = wfdb.rdann(path + record_name, 'atr')

        signals = record.p_signal[:, 0]  # Taking Lead I for simplicity
        signals = denoise(signals)

        # Process the annotations to extract beats
        for i in range(len(annotation.sample)):
            arrhythmia_type = annotation.symbol[i]

            # Plot an example to the signals
            if i == 1 and record_name == '101':
                # Plot each patient's signal
                plt.figure(figsize=(12, 3))
                plt.title(f"700 Datapoints From Record {record_name} Wave")
                plt.plot(signals[0:700])
                plt.grid(True)
                plt.show()

            if arrhythmia_type in classes:
                arrhythmia_index = classes.index(arrhythmia_type)
                pos = annotation.sample[i]  # Position of the R-peak (sample index)

                # Ensure we don't go out of bounds when extracting the beat
                if window_size//2 <= pos < len(signals) - window_size//2:
                    beat = signals[pos-window_size//2:pos+window_size//2]

                    # Plot an example beat (once)
                    if record_name == '101' and not example_beat_printed:
                        print() # Print an empty space before figure
                        plt.figure(figsize=(6, 3))
                        plt.title(f"A Single Beat From Record {record_name} Wave")
                        plt.plot(beat)
                        plt.grid(True)
                        plt.show()
                        example_beat_printed = True

                    X.append(beat)  # 300 point ECG vectors
                    y.append(arrhythmia_index)  # Arrhythmia class labels
                    count_classes[arrhythmia_index] += 1

print() # Print an empty space
print(np.shape(X), np.shape(y))
print("Class distribution:", count_classes)
# Out:
# (100017, 300) (100017,)
# Class distribution: [75016, 8071, 7255, 2546, 7129]

# %%
# Creating a data frame
X_df = pd.DataFrame(X)
X_df[len(X[0])] = y
X_df.shape
# Out:
# (100017, 301)

# %%
# Distribution of data
per_class = X_df[X_df.shape[1]-1].value_counts()

plt.figure(figsize=(7,7))
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(per_class, labels=['N', 'L', 'R', 'A', 'V'], colors=['tab:blue','tab:orange','tab:purple','tab:olive','tab:green'],autopct='%1.1f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %%
# Resampling the dataset to get to an even distribution
# TEST_SET_SIZE test data and TRAIN_SET_SIZE training data from each class
n_train = TRAIN_SET_SIZE
n_test = TEST_SET_SIZE
n_total = n_train + n_test

test_ratio = n_test/(n_total)

train = pd.DataFrame()
test = pd.DataFrame()

for class_value in range(5):

    # Filter the dataframe for the current class
    df_class = X_df[X_df[300] == class_value]

    # Randomly sample 2500 rows (or all rows if less )
    df_sampled_class = df_class.sample(n=min(n_total, len(df_class)), random_state=42)

    train_class, test_class = train_test_split(df_sampled_class, test_size= test_ratio)

    # Append the sampled rows to the new dataframe
    train = pd.concat([train, train_class])
    test = pd.concat([test, test_class])

# Reset index of the new dataframe
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

# Display the new dataframe
train.shape, test.shape
# Out:
# ((10000, 301), (2500, 301))

# %%
per_class = train[train.shape[1]-1].value_counts()
print(per_class)
# Out:
# 300
# 0    2000
# 1    2000
# 2    2000
# 3    2000
# 4    2000
# Name: count, dtype: int64

# %%
# X_filtered = denoise(X[0])

# # Create a figure and two subplots
# fig, axs = plt.subplots(1, 2, figsize=(12, 3))  # 1 rows, 2 columns

# # Plot the original signal in the first subplot
# axs[0].plot(X[0])
# axs[0].set_title('Original Signal')
# axs[0].grid(True)

# # Plot the filtered signal in the second subplot
# axs[1].plot(X_filtered)
# axs[1].set_title('Filtered Signal')
# axs[1].grid(True)

# # Adjust the layout
# plt.tight_layout()

# # Show the plots
# plt.show()

# %%
# # Test code for less IMFs than expected
# array = test.iloc[0:1].to_numpy().flatten()
# t = array[:-1]
# IMFs = emd(t, max_imf=EMD_IMFS)

# df_test = get_features_df(test.iloc[0:1], "emd")
# print(df_test.shape)
# df_test.head()

# %%
# # Execute EMD on signal
# IMFs = emd(X[0], max_imf=EMD_IMFS)
# N = IMFs.shape[0] # Number of subplots

# plt.figure(figsize=(10, 2*N))  # Adjust the height based on the number of IMFs

# # Plot the input signal
# plt.subplot(N, 1, 1)
# plt.plot(X[0], "r")
# plt.title("Input Signal: X[0]")
# plt.grid(True)

# # Plot each IMF
# for n, imf in enumerate(IMFs[:-1]):
#     plt.subplot(N, 1, n + 2)
#     plt.plot(imf, "g")
#     plt.title(f"IMF {n + 1}")
#     plt.grid(True)

# # Show the plot
# plt.tight_layout()
# plt.show()

# %%
# # Test code for creating feature vector
# t = X_df.iloc[1:2]
# df_test = get_features_df(t, "emd")
# print(df_test.shape)

# %%
train_features_df = get_features_df(train, "emd")
# test_features_df = get_features_df(test, "emd")
# Out:
# Streaming output truncated to the last 5000 lines.
# Decomposed segment 5003; Extracted features from segment 5003; Created a dataframe for segment 5003.
# Decomposed segment 5004; Extracted features from segment 5004; Created a dataframe for segment 5004.
# Decomposed segment 5005; Extracted features from segment 5005; Created a dataframe for segment 5005.
# Decomposed segment 5006; Extracted features from segment 5006; Created a dataframe for segment 5006.
# Decomposed segment 5007; Extracted features from segment 5007; Created a dataframe for segment 5007.
# Decomposed segment 5008; Extracted features from segment 5008; Created a dataframe for segment 5008.
# Decomposed segment 5009; Extracted features from segment 5009; Created a dataframe for segment 5009.
# Decomposed segment 5010; Extracted features from segment 5010; Created a dataframe for segment 5010.
# Decomposed segment 5011; Extracted features from segment 5011; Created a dataframe for segment 5011.
# Decomposed segment 5012; Extracted features from segment 5012; Created a dataframe for segment 5012.
# Decomposed segment 5013; Extracted features from segment 5013; Created a dataframe for segment 5013.
# Decomposed segment 5014; Extracted features from segment 5014; Created a dataframe for segment 5014.
# Decomposed segment 5015; Extracted features from segment 5015; Created a dataframe for segment 5015.
# Decomposed segment 5016; Extracted features from segment 5016; Created a dataframe for segment 5016.
# Decomposed segment 5017; Extracted features from segment 5017; Created a dataframe for segment 5017.
# Decomposed segment 5018; Extracted features from segment 5018; Created a dataframe for segment 5018.
# Decomposed segment 5019; Extracted features from segment 5019; Created a dataframe for segment 5019.
# Decomposed segment 5020; Extracted features from segment 5020; Created a dataframe for segment 5020.
# Decomposed segment 5021; Extracted features from segment 5021; Created a dataframe for segment 5021.
# Decomposed segment 5022; Extracted features from segment 5022; Created a dataframe for segment 5022.
# Decomposed segment 5023; Extracted features from segment 5023; Created a dataframe for segment 5023.
# Decomposed segment 5024; Extracted features from segment 5024; Created a dataframe for segment 5024.
# Decomposed segment 5025; Extracted features from segment 5025; Created a dataframe for segment 5025.
# Decomposed segment 5026; Extracted features from segment 5026; Created a dataframe for segment 5026.
# Decomposed segment 5027; Extracted features from segment 5027; Created a dataframe for segment 5027.
# Decomposed segment 5028; Extracted features from segment 5028; Created a dataframe for segment 5028.
# Decomposed segment 5029; Extracted features from segment 5029; Created a dataframe for segment 5029.
# Decomposed segment 5030; Extracted features from segment 5030; Created a dataframe for segment 5030.
# Decomposed segment 5031; Extracted features from segment 5031; Created a dataframe for segment 5031.
# Decomposed segment 5032; Extracted features from segment 5032; Created a dataframe for segment 5032.
# Decomposed segment 5033; Extracted features from segment 5033; Created a dataframe for segment 5033.
# Decomposed segment 5034; Extracted features from segment 5034; Created a dataframe for segment 5034.
# Decomposed segment 5035; Extracted features from segment 5035; Created a dataframe for segment 5035.
# Decomposed segment 5036; Extracted features from segment 5036; Created a dataframe for segment 5036.
# Decomposed segment 5037; Extracted features from segment 5037; Created a dataframe for segment 5037.
# Decomposed segment 5038; Extracted features from segment 5038; Created a dataframe for segment 5038.
# Decomposed segment 5039; Extracted features from segment 5039; Created a dataframe for segment 5039.
# Decomposed segment 5040; Extracted features from segment 5040; Created a dataframe for segment 5040.
# Decomposed segment 5041; Extracted features from segment 5041; Created a dataframe for segment 5041.
# Decomposed segment 5042; Extracted features from segment 5042; Created a dataframe for segment 5042.
# Decomposed segment 5043; Extracted features from segment 5043; Created a dataframe for segment 5043.
# Decomposed segment 5044; Extracted features from segment 5044; Created a dataframe for segment 5044.
# Decomposed segment 5045; Extracted features from segment 5045; Created a dataframe for segment 5045.
# Decomposed segment 5046; Extracted features from segment 5046; Created a dataframe for segment 5046.
# Decomposed segment 5047; Extracted features from segment 5047; Created a dataframe for segment 5047.
# Decomposed segment 5048; Extracted features from segment 5048; Created a dataframe for segment 5048.
# Decomposed segment 5049; Extracted features from segment 5049; Created a dataframe for segment 5049.
# Decomposed segment 5050; Extracted features from segment 5050; Created a dataframe for segment 5050.
# Decomposed segment 5051; Extracted features from segment 5051; Created a dataframe for segment 5051.
# Decomposed segment 5052; Extracted features from segment 5052; Created a dataframe for segment 5052.
# Decomposed segment 5053; Extracted features from segment 5053; Created a dataframe for segment 5053.
# Decomposed segment 5054; Extracted features from segment 5054; Created a dataframe for segment 5054.
# Decomposed segment 5055; Extracted features from segment 5055; Created a dataframe for segment 5055.
# Decomposed segment 5056; Extracted features from segment 5056; Created a dataframe for segment 5056.
# Decomposed segment 5057; Extracted features from segment 5057; Created a dataframe for segment 5057.
# Decomposed segment 5058; Extracted features from segment 5058; Created a dataframe for segment 5058.
# Decomposed segment 5059; Extracted features from segment 5059; Created a dataframe for segment 5059.
# Decomposed segment 5060; Extracted features from segment 5060; Created a dataframe for segment 5060.
# Decomposed segment 5061; Extracted features from segment 5061; Created a dataframe for segment 5061.
# Decomposed segment 5062; Extracted features from segment 5062; Created a dataframe for segment 5062.
# Decomposed segment 5063; Extracted features from segment 5063; Created a dataframe for segment 5063.
# Decomposed segment 5064; Extracted features from segment 5064; Created a dataframe for segment 5064.
# Decomposed segment 5065; Extracted features from segment 5065; Created a dataframe for segment 5065.
# Decomposed segment 5066; Extracted features from segment 5066; Created a dataframe for segment 5066.
# Decomposed segment 5067; Extracted features from segment 5067; Created a dataframe for segment 5067.
# Decomposed segment 5068; Extracted features from segment 5068; Created a dataframe for segment 5068.
# Decomposed segment 5069; Extracted features from segment 5069; Created a dataframe for segment 5069.
# Decomposed segment 5070; Extracted features from segment 5070; Created a dataframe for segment 5070.
# Decomposed segment 5071; Extracted features from segment 5071; Created a dataframe for segment 5071.
# Decomposed segment 5072; Extracted features from segment 5072; Created a dataframe for segment 5072.
# Decomposed segment 5073; Extracted features from segment 5073; Created a dataframe for segment 5073.
# Decomposed segment 5074; Extracted features from segment 5074; Created a dataframe for segment 5074.
# Decomposed segment 5075; Extracted features from segment 5075; Created a dataframe for segment 5075.
# Decomposed segment 5076; Extracted features from segment 5076; Created a dataframe for segment 5076.
# Decomposed segment 5077; Extracted features from segment 5077; Created a dataframe for segment 5077.
# Decomposed segment 5078; Extracted features from segment 5078; Created a dataframe for segment 5078.
# Decomposed segment 5079; Extracted features from segment 5079; Created a dataframe for segment 5079.
# Decomposed segment 5080; Extracted features from segment 5080; Created a dataframe for segment 5080.
# Decomposed segment 5081; Extracted features from segment 5081; Created a dataframe for segment 5081.
# Decomposed segment 5082; Extracted features from segment 5082; Created a dataframe for segment 5082.
# Decomposed segment 5083; Extracted features from segment 5083; Created a dataframe for segment 5083.
# Decomposed segment 5084; Extracted features from segment 5084; Created a dataframe for segment 5084.
# Decomposed segment 5085; Extracted features from segment 5085; Created a dataframe for segment 5085.
# Decomposed segment 5086; Extracted features from segment 5086; Created a dataframe for segment 5086.
# Decomposed segment 5087; Extracted features from segment 5087; Created a dataframe for segment 5087.
# Decomposed segment 5088; Extracted features from segment 5088; Created a dataframe for segment 5088.
# Decomposed segment 5089; Extracted features from segment 5089; Created a dataframe for segment 5089.
# Decomposed segment 5090; Extracted features from segment 5090; Created a dataframe for segment 5090.
# Decomposed segment 5091; Extracted features from segment 5091; Created a dataframe for segment 5091.
# Decomposed segment 5092; Extracted features from segment 5092; Created a dataframe for segment 5092.
# Decomposed segment 5093; Extracted features from segment 5093; Created a dataframe for segment 5093.
# Decomposed segment 5094; Extracted features from segment 5094; Created a dataframe for segment 5094.
# Decomposed segment 5095; Extracted features from segment 5095; Created a dataframe for segment 5095.
# Decomposed segment 5096; Extracted features from segment 5096; Created a dataframe for segment 5096.
# Decomposed segment 5097; Extracted features from segment 5097; Created a dataframe for segment 5097.
# Decomposed segment 5098; Extracted features from segment 5098; Created a dataframe for segment 5098.
# Decomposed segment 5099; Extracted features from segment 5099; Created a dataframe for segment 5099.
# Decomposed segment 5100; Extracted features from segment 5100; Created a dataframe for segment 5100.
# Decomposed segment 5101; Extracted features from segment 5101; Created a dataframe for segment 5101.
# Decomposed segment 5102; Extracted features from segment 5102; Created a dataframe for segment 5102.
# Decomposed segment 5103; Extracted features from segment 5103; Created a dataframe for segment 5103.
# Decomposed segment 5104; Extracted features from segment 5104; Created a dataframe for segment 5104.
# Decomposed segment 5105; Extracted features from segment 5105; Created a dataframe for segment 5105.
# Decomposed segment 5106; Extracted features from segment 5106; Created a dataframe for segment 5106.
# Decomposed segment 5107; Extracted features from segment 5107; Created a dataframe for segment 5107.
# Decomposed segment 5108; Extracted features from segment 5108; Created a dataframe for segment 5108.
# Decomposed segment 5109; Extracted features from segment 5109; Created a dataframe for segment 5109.
# Decomposed segment 5110; Extracted features from segment 5110; Created a dataframe for segment 5110.
# Decomposed segment 5111; Extracted features from segment 5111; Created a dataframe for segment 5111.
# Decomposed segment 5112; Extracted features from segment 5112; Created a dataframe for segment 5112.
# Decomposed segment 5113; Extracted features from segment 5113; Created a dataframe for segment 5113.
# Decomposed segment 5114; Extracted features from segment 5114; Created a dataframe for segment 5114.
# Decomposed segment 5115; Extracted features from segment 5115; Created a dataframe for segment 5115.
# Decomposed segment 5116; Extracted features from segment 5116; Created a dataframe for segment 5116.
# Decomposed segment 5117; Extracted features from segment 5117; Created a dataframe for segment 5117.
# Decomposed segment 5118; Extracted features from segment 5118; Created a dataframe for segment 5118.
# Decomposed segment 5119; Extracted features from segment 5119; Created a dataframe for segment 5119.
# Decomposed segment 5120; Extracted features from segment 5120; Created a dataframe for segment 5120.
# Decomposed segment 5121; Extracted features from segment 5121; Created a dataframe for segment 5121.
# Decomposed segment 5122; Extracted features from segment 5122; Created a dataframe for segment 5122.
# Decomposed segment 5123; Extracted features from segment 5123; Created a dataframe for segment 5123.
# Decomposed segment 5124; Extracted features from segment 5124; Created a dataframe for segment 5124.
# Decomposed segment 5125; Extracted features from segment 5125; Created a dataframe for segment 5125.
# Decomposed segment 5126; Extracted features from segment 5126; Created a dataframe for segment 5126.
# Decomposed segment 5127; Extracted features from segment 5127; Created a dataframe for segment 5127.
# Decomposed segment 5128; Extracted features from segment 5128; Created a dataframe for segment 5128.
# Decomposed segment 5129; Extracted features from segment 5129; Created a dataframe for segment 5129.
# Decomposed segment 5130; Extracted features from segment 5130; Created a dataframe for segment 5130.
# Decomposed segment 5131; Extracted features from segment 5131; Created a dataframe for segment 5131.
# Decomposed segment 5132; Extracted features from segment 5132; Created a dataframe for segment 5132.
# Decomposed segment 5133; Extracted features from segment 5133; Created a dataframe for segment 5133.
# Decomposed segment 5134; Extracted features from segment 5134; Created a dataframe for segment 5134.
# Decomposed segment 5135; Extracted features from segment 5135; Created a dataframe for segment 5135.
# Decomposed segment 5136; Extracted features from segment 5136; Created a dataframe for segment 5136.
# Decomposed segment 5137; Extracted features from segment 5137; Created a dataframe for segment 5137.
# Decomposed segment 5138; Extracted features from segment 5138; Created a dataframe for segment 5138.
# Decomposed segment 5139; Extracted features from segment 5139; Created a dataframe for segment 5139.
# Decomposed segment 5140; Extracted features from segment 5140; Created a dataframe for segment 5140.
# Decomposed segment 5141; Extracted features from segment 5141; Created a dataframe for segment 5141.
# Decomposed segment 5142; Extracted features from segment 5142; Created a dataframe for segment 5142.
# Decomposed segment 5143; Extracted features from segment 5143; Created a dataframe for segment 5143.
# Decomposed segment 5144; Extracted features from segment 5144; Created a dataframe for segment 5144.
# Decomposed segment 5145; Extracted features from segment 5145; Created a dataframe for segment 5145.
# Decomposed segment 5146; Extracted features from segment 5146; Created a dataframe for segment 5146.
# Decomposed segment 5147; Extracted features from segment 5147; Created a dataframe for segment 5147.
# Decomposed segment 5148; Extracted features from segment 5148; Created a dataframe for segment 5148.
# Decomposed segment 5149; Extracted features from segment 5149; Created a dataframe for segment 5149.
# Decomposed segment 5150; Extracted features from segment 5150; Created a dataframe for segment 5150.
# Decomposed segment 5151; Extracted features from segment 5151; Created a dataframe for segment 5151.
# Decomposed segment 5152; Extracted features from segment 5152; Created a dataframe for segment 5152.
# Decomposed segment 5153; Extracted features from segment 5153; Created a dataframe for segment 5153.
# Decomposed segment 5154; Extracted features from segment 5154; Created a dataframe for segment 5154.
# Decomposed segment 5155; Extracted features from segment 5155; Created a dataframe for segment 5155.
# Decomposed segment 5156; Extracted features from segment 5156; Created a dataframe for segment 5156.
# Decomposed segment 5157; Extracted features from segment 5157; Created a dataframe for segment 5157.
# Decomposed segment 5158; Extracted features from segment 5158; Created a dataframe for segment 5158.
# Decomposed segment 5159; Extracted features from segment 5159; Created a dataframe for segment 5159.
# Decomposed segment 5160; Extracted features from segment 5160; Created a dataframe for segment 5160.
# Decomposed segment 5161; Extracted features from segment 5161; Created a dataframe for segment 5161.
# Decomposed segment 5162; Extracted features from segment 5162; Created a dataframe for segment 5162.
# Decomposed segment 5163; Extracted features from segment 5163; Created a dataframe for segment 5163.
# Decomposed segment 5164; Extracted features from segment 5164; Created a dataframe for segment 5164.
# Decomposed segment 5165; Extracted features from segment 5165; Created a dataframe for segment 5165.
# Decomposed segment 5166; Extracted features from segment 5166; Created a dataframe for segment 5166.
# Decomposed segment 5167; Extracted features from segment 5167; Created a dataframe for segment 5167.
# Decomposed segment 5168; Extracted features from segment 5168; Created a dataframe for segment 5168.
# Decomposed segment 5169; Extracted features from segment 5169; Created a dataframe for segment 5169.
# Decomposed segment 5170; Extracted features from segment 5170; Created a dataframe for segment 5170.
# Decomposed segment 5171; Extracted features from segment 5171; Created a dataframe for segment 5171.
# Decomposed segment 5172; Extracted features from segment 5172; Created a dataframe for segment 5172.
# Decomposed segment 5173; Extracted features from segment 5173; Created a dataframe for segment 5173.
# Decomposed segment 5174; Extracted features from segment 5174; Created a dataframe for segment 5174.
# Decomposed segment 5175; Extracted features from segment 5175; Created a dataframe for segment 5175.
# Decomposed segment 5176; Extracted features from segment 5176; Created a dataframe for segment 5176.
# Decomposed segment 5177; Extracted features from segment 5177; Created a dataframe for segment 5177.
# Decomposed segment 5178; Extracted features from segment 5178; Created a dataframe for segment 5178.
# Decomposed segment 5179; Extracted features from segment 5179; Created a dataframe for segment 5179.
# Decomposed segment 5180; Extracted features from segment 5180; Created a dataframe for segment 5180.
# Decomposed segment 5181; Extracted features from segment 5181; Created a dataframe for segment 5181.
# Decomposed segment 5182; Extracted features from segment 5182; Created a dataframe for segment 5182.
# Decomposed segment 5183; Extracted features from segment 5183; Created a dataframe for segment 5183.
# Decomposed segment 5184; Extracted features from segment 5184; Created a dataframe for segment 5184.
# Decomposed segment 5185; Extracted features from segment 5185; Created a dataframe for segment 5185.
# Decomposed segment 5186; Extracted features from segment 5186; Created a dataframe for segment 5186.
# Decomposed segment 5187; Extracted features from segment 5187; Created a dataframe for segment 5187.
# Decomposed segment 5188; Extracted features from segment 5188; Created a dataframe for segment 5188.
# Decomposed segment 5189; Extracted features from segment 5189; Created a dataframe for segment 5189.
# Decomposed segment 5190; Extracted features from segment 5190; Created a dataframe for segment 5190.
# Decomposed segment 5191; Extracted features from segment 5191; Created a dataframe for segment 5191.
# Decomposed segment 5192; Extracted features from segment 5192; Created a dataframe for segment 5192.
# Decomposed segment 5193; Extracted features from segment 5193; Created a dataframe for segment 5193.
# Decomposed segment 5194; Extracted features from segment 5194; Created a dataframe for segment 5194.
# Decomposed segment 5195; Extracted features from segment 5195; Created a dataframe for segment 5195.
# Decomposed segment 5196; Extracted features from segment 5196; Created a dataframe for segment 5196.
# Decomposed segment 5197; Extracted features from segment 5197; Created a dataframe for segment 5197.
# Decomposed segment 5198; Extracted features from segment 5198; Created a dataframe for segment 5198.
# Decomposed segment 5199; Extracted features from segment 5199; Created a dataframe for segment 5199.
# Decomposed segment 5200; Extracted features from segment 5200; Created a dataframe for segment 5200.
# Decomposed segment 5201; Extracted features from segment 5201; Created a dataframe for segment 5201.
# Decomposed segment 5202; Extracted features from segment 5202; Created a dataframe for segment 5202.
# Decomposed segment 5203; Extracted features from segment 5203; Created a dataframe for segment 5203.
# Decomposed segment 5204; Extracted features from segment 5204; Created a dataframe for segment 5204.
# Decomposed segment 5205; Extracted features from segment 5205; Created a dataframe for segment 5205.
# Decomposed segment 5206; Extracted features from segment 5206; Created a dataframe for segment 5206.
# Decomposed segment 5207; Extracted features from segment 5207; Created a dataframe for segment 5207.
# Decomposed segment 5208; Extracted features from segment 5208; Created a dataframe for segment 5208.
# Decomposed segment 5209; Extracted features from segment 5209; Created a dataframe for segment 5209.
# Decomposed segment 5210; Extracted features from segment 5210; Created a dataframe for segment 5210.
# Decomposed segment 5211; Extracted features from segment 5211; Created a dataframe for segment 5211.
# Decomposed segment 5212; Extracted features from segment 5212; Created a dataframe for segment 5212.
# Decomposed segment 5213; Extracted features from segment 5213; Created a dataframe for segment 5213.
# Decomposed segment 5214; Extracted features from segment 5214; Created a dataframe for segment 5214.
# Decomposed segment 5215; Extracted features from segment 5215; Created a dataframe for segment 5215.
# Decomposed segment 5216; Extracted features from segment 5216; Created a dataframe for segment 5216.
# Decomposed segment 5217; Extracted features from segment 5217; Created a dataframe for segment 5217.
# Decomposed segment 5218; Extracted features from segment 5218; Created a dataframe for segment 5218.
# Decomposed segment 5219; Extracted features from segment 5219; Created a dataframe for segment 5219.
# Decomposed segment 5220; Extracted features from segment 5220; Created a dataframe for segment 5220.
# Decomposed segment 5221; Extracted features from segment 5221; Created a dataframe for segment 5221.
# Decomposed segment 5222; Extracted features from segment 5222; Created a dataframe for segment 5222.
# Decomposed segment 5223; Extracted features from segment 5223; Created a dataframe for segment 5223.
# Decomposed segment 5224; Extracted features from segment 5224; Created a dataframe for segment 5224.
# Decomposed segment 5225; Extracted features from segment 5225; Created a dataframe for segment 5225.
# Decomposed segment 5226; Extracted features from segment 5226; Created a dataframe for segment 5226.
# Decomposed segment 5227; Extracted features from segment 5227; Created a dataframe for segment 5227.
# Decomposed segment 5228; Extracted features from segment 5228; Created a dataframe for segment 5228.
# Decomposed segment 5229; Extracted features from segment 5229; Created a dataframe for segment 5229.
# Decomposed segment 5230; Extracted features from segment 5230; Created a dataframe for segment 5230.
# Decomposed segment 5231; Extracted features from segment 5231; Created a dataframe for segment 5231.
# Decomposed segment 5232; Extracted features from segment 5232; Created a dataframe for segment 5232.
# Decomposed segment 5233; Extracted features from segment 5233; Created a dataframe for segment 5233.
# Decomposed segment 5234; Extracted features from segment 5234; Created a dataframe for segment 5234.
# Decomposed segment 5235; Extracted features from segment 5235; Created a dataframe for segment 5235.
# Decomposed segment 5236; Extracted features from segment 5236; Created a dataframe for segment 5236.
# Decomposed segment 5237; Extracted features from segment 5237; Created a dataframe for segment 5237.
# Decomposed segment 5238; Extracted features from segment 5238; Created a dataframe for segment 5238.
# Decomposed segment 5239; Extracted features from segment 5239; Created a dataframe for segment 5239.
# Decomposed segment 5240; Extracted features from segment 5240; Created a dataframe for segment 5240.
# Decomposed segment 5241; Extracted features from segment 5241; Created a dataframe for segment 5241.
# Decomposed segment 5242; Extracted features from segment 5242; Created a dataframe for segment 5242.
# Decomposed segment 5243; Extracted features from segment 5243; Created a dataframe for segment 5243.
# Decomposed segment 5244; Extracted features from segment 5244; Created a dataframe for segment 5244.
# Decomposed segment 5245; Extracted features from segment 5245; Created a dataframe for segment 5245.
# Decomposed segment 5246; Extracted features from segment 5246; Created a dataframe for segment 5246.
# Decomposed segment 5247; Extracted features from segment 5247; Created a dataframe for segment 5247.
# Decomposed segment 5248; Extracted features from segment 5248; Created a dataframe for segment 5248.
# Decomposed segment 5249; Extracted features from segment 5249; Created a dataframe for segment 5249.
# Decomposed segment 5250; Extracted features from segment 5250; Created a dataframe for segment 5250.
# Decomposed segment 5251; Extracted features from segment 5251; Created a dataframe for segment 5251.
# Decomposed segment 5252; Extracted features from segment 5252; Created a dataframe for segment 5252.
# Decomposed segment 5253; Extracted features from segment 5253; Created a dataframe for segment 5253.
# Decomposed segment 5254; Extracted features from segment 5254; Created a dataframe for segment 5254.
# Decomposed segment 5255; Extracted features from segment 5255; Created a dataframe for segment 5255.
# Decomposed segment 5256; Extracted features from segment 5256; Created a dataframe for segment 5256.
# Decomposed segment 5257; Extracted features from segment 5257; Created a dataframe for segment 5257.
# Decomposed segment 5258; Extracted features from segment 5258; Created a dataframe for segment 5258.
# Decomposed segment 5259; Extracted features from segment 5259; Created a dataframe for segment 5259.
# Decomposed segment 5260; Extracted features from segment 5260; Created a dataframe for segment 5260.
# Decomposed segment 5261; Extracted features from segment 5261; Created a dataframe for segment 5261.
# Decomposed segment 5262; Extracted features from segment 5262; Created a dataframe for segment 5262.
# Decomposed segment 5263; Extracted features from segment 5263; Created a dataframe for segment 5263.
# Decomposed segment 5264; Extracted features from segment 5264; Created a dataframe for segment 5264.
# Decomposed segment 5265; Extracted features from segment 5265; Created a dataframe for segment 5265.
# Decomposed segment 5266; Extracted features from segment 5266; Created a dataframe for segment 5266.
# Decomposed segment 5267; Extracted features from segment 5267; Created a dataframe for segment 5267.
# Decomposed segment 5268; Extracted features from segment 5268; Created a dataframe for segment 5268.
# Decomposed segment 5269; Extracted features from segment 5269; Created a dataframe for segment 5269.
# Decomposed segment 5270; Extracted features from segment 5270; Created a dataframe for segment 5270.
# Decomposed segment 5271; Extracted features from segment 5271; Created a dataframe for segment 5271.
# Decomposed segment 5272; Extracted features from segment 5272; Created a dataframe for segment 5272.
# Decomposed segment 5273; Extracted features from segment 5273; Created a dataframe for segment 5273.
# Decomposed segment 5274; Extracted features from segment 5274; Created a dataframe for segment 5274.
# Decomposed segment 5275; Extracted features from segment 5275; Created a dataframe for segment 5275.
# Decomposed segment 5276; Extracted features from segment 5276; Created a dataframe for segment 5276.
# Decomposed segment 5277; Extracted features from segment 5277; Created a dataframe for segment 5277.
# Decomposed segment 5278; Extracted features from segment 5278; Created a dataframe for segment 5278.
# Decomposed segment 5279; Extracted features from segment 5279; Created a dataframe for segment 5279.
# Decomposed segment 5280; Extracted features from segment 5280; Created a dataframe for segment 5280.
# Decomposed segment 5281; Extracted features from segment 5281; Created a dataframe for segment 5281.
# Decomposed segment 5282; Extracted features from segment 5282; Created a dataframe for segment 5282.
# Decomposed segment 5283; Extracted features from segment 5283; Created a dataframe for segment 5283.
# Decomposed segment 5284; Extracted features from segment 5284; Created a dataframe for segment 5284.
# Decomposed segment 5285; Extracted features from segment 5285; Created a dataframe for segment 5285.
# Decomposed segment 5286; Extracted features from segment 5286; Created a dataframe for segment 5286.
# Decomposed segment 5287; Extracted features from segment 5287; Created a dataframe for segment 5287.
# Decomposed segment 5288; Extracted features from segment 5288; Created a dataframe for segment 5288.
# Decomposed segment 5289; Extracted features from segment 5289; Created a dataframe for segment 5289.
# Decomposed segment 5290; Extracted features from segment 5290; Created a dataframe for segment 5290.
# Decomposed segment 5291; Extracted features from segment 5291; Created a dataframe for segment 5291.
# Decomposed segment 5292; Extracted features from segment 5292; Created a dataframe for segment 5292.
# Decomposed segment 5293; Extracted features from segment 5293; Created a dataframe for segment 5293.
# Decomposed segment 5294; Extracted features from segment 5294; Created a dataframe for segment 5294.
# Decomposed segment 5295; Extracted features from segment 5295; Created a dataframe for segment 5295.
# Decomposed segment 5296; Extracted features from segment 5296; Created a dataframe for segment 5296.
# Decomposed segment 5297; Extracted features from segment 5297; Created a dataframe for segment 5297.
# Decomposed segment 5298; Extracted features from segment 5298; Created a dataframe for segment 5298.
# Decomposed segment 5299; Extracted features from segment 5299; Created a dataframe for segment 5299.
# Decomposed segment 5300; Extracted features from segment 5300; Created a dataframe for segment 5300.
# Decomposed segment 5301; Extracted features from segment 5301; Created a dataframe for segment 5301.
# Decomposed segment 5302; Extracted features from segment 5302; Created a dataframe for segment 5302.
# Decomposed segment 5303; Extracted features from segment 5303; Created a dataframe for segment 5303.
# Decomposed segment 5304; Extracted features from segment 5304; Created a dataframe for segment 5304.
# Decomposed segment 5305; Extracted features from segment 5305; Created a dataframe for segment 5305.
# Decomposed segment 5306; Extracted features from segment 5306; Created a dataframe for segment 5306.
# Decomposed segment 5307; Extracted features from segment 5307; Created a dataframe for segment 5307.
# Decomposed segment 5308; Extracted features from segment 5308; Created a dataframe for segment 5308.
# Decomposed segment 5309; Extracted features from segment 5309; Created a dataframe for segment 5309.
# Decomposed segment 5310; Extracted features from segment 5310; Created a dataframe for segment 5310.
# Decomposed segment 5311; Extracted features from segment 5311; Created a dataframe for segment 5311.
# Decomposed segment 5312; Extracted features from segment 5312; Created a dataframe for segment 5312.
# Decomposed segment 5313; Extracted features from segment 5313; Created a dataframe for segment 5313.
# Decomposed segment 5314; Extracted features from segment 5314; Created a dataframe for segment 5314.
# Decomposed segment 5315; Extracted features from segment 5315; Created a dataframe for segment 5315.
# Decomposed segment 5316; Extracted features from segment 5316; Created a dataframe for segment 5316.
# Decomposed segment 5317; Extracted features from segment 5317; Created a dataframe for segment 5317.
# Decomposed segment 5318; Extracted features from segment 5318; Created a dataframe for segment 5318.
# Decomposed segment 5319; Extracted features from segment 5319; Created a dataframe for segment 5319.
# Decomposed segment 5320; Extracted features from segment 5320; Created a dataframe for segment 5320.
# Decomposed segment 5321; Extracted features from segment 5321; Created a dataframe for segment 5321.
# Decomposed segment 5322; Extracted features from segment 5322; Created a dataframe for segment 5322.
# Decomposed segment 5323; Extracted features from segment 5323; Created a dataframe for segment 5323.
# Decomposed segment 5324; Extracted features from segment 5324; Created a dataframe for segment 5324.
# Decomposed segment 5325; Extracted features from segment 5325; Created a dataframe for segment 5325.
# Decomposed segment 5326; Extracted features from segment 5326; Created a dataframe for segment 5326.
# Decomposed segment 5327; Extracted features from segment 5327; Created a dataframe for segment 5327.
# Decomposed segment 5328; Extracted features from segment 5328; Created a dataframe for segment 5328.
# Decomposed segment 5329; Extracted features from segment 5329; Created a dataframe for segment 5329.
# Decomposed segment 5330; Extracted features from segment 5330; Created a dataframe for segment 5330.
# Decomposed segment 5331; Extracted features from segment 5331; Created a dataframe for segment 5331.
# Decomposed segment 5332; Extracted features from segment 5332; Created a dataframe for segment 5332.
# Decomposed segment 5333; Extracted features from segment 5333; Created a dataframe for segment 5333.
# Decomposed segment 5334; Extracted features from segment 5334; Created a dataframe for segment 5334.
# Decomposed segment 5335; Extracted features from segment 5335; Created a dataframe for segment 5335.
# Decomposed segment 5336; Extracted features from segment 5336; Created a dataframe for segment 5336.
# Decomposed segment 5337; Extracted features from segment 5337; Created a dataframe for segment 5337.
# Decomposed segment 5338; Extracted features from segment 5338; Created a dataframe for segment 5338.
# Decomposed segment 5339; Extracted features from segment 5339; Created a dataframe for segment 5339.
# Decomposed segment 5340; Extracted features from segment 5340; Created a dataframe for segment 5340.
# Decomposed segment 5341; Extracted features from segment 5341; Created a dataframe for segment 5341.
# Decomposed segment 5342; Extracted features from segment 5342; Created a dataframe for segment 5342.
# Decomposed segment 5343; Extracted features from segment 5343; Created a dataframe for segment 5343.
# Decomposed segment 5344; Extracted features from segment 5344; Created a dataframe for segment 5344.
# Decomposed segment 5345; Extracted features from segment 5345; Created a dataframe for segment 5345.
# Decomposed segment 5346; Extracted features from segment 5346; Created a dataframe for segment 5346.
# Decomposed segment 5347; Extracted features from segment 5347; Created a dataframe for segment 5347.
# Decomposed segment 5348; Extracted features from segment 5348; Created a dataframe for segment 5348.
# Decomposed segment 5349; Extracted features from segment 5349; Created a dataframe for segment 5349.
# Decomposed segment 5350; Extracted features from segment 5350; Created a dataframe for segment 5350.
# Decomposed segment 5351; Extracted features from segment 5351; Created a dataframe for segment 5351.
# Decomposed segment 5352; Extracted features from segment 5352; Created a dataframe for segment 5352.
# Decomposed segment 5353; Extracted features from segment 5353; Created a dataframe for segment 5353.
# Decomposed segment 5354; Extracted features from segment 5354; Created a dataframe for segment 5354.
# Decomposed segment 5355; Extracted features from segment 5355; Created a dataframe for segment 5355.
# Decomposed segment 5356; Extracted features from segment 5356; Created a dataframe for segment 5356.
# Decomposed segment 5357; Extracted features from segment 5357; Created a dataframe for segment 5357.
# Decomposed segment 5358; Extracted features from segment 5358; Created a dataframe for segment 5358.
# Decomposed segment 5359; Extracted features from segment 5359; Created a dataframe for segment 5359.
# Decomposed segment 5360; Extracted features from segment 5360; Created a dataframe for segment 5360.
# Decomposed segment 5361; Extracted features from segment 5361; Created a dataframe for segment 5361.
# Decomposed segment 5362; Extracted features from segment 5362; Created a dataframe for segment 5362.
# Decomposed segment 5363; Extracted features from segment 5363; Created a dataframe for segment 5363.
# Decomposed segment 5364; Extracted features from segment 5364; Created a dataframe for segment 5364.
# Decomposed segment 5365; Extracted features from segment 5365; Created a dataframe for segment 5365.
# Decomposed segment 5366; Extracted features from segment 5366; Created a dataframe for segment 5366.
# Decomposed segment 5367; Extracted features from segment 5367; Created a dataframe for segment 5367.
# Decomposed segment 5368; Extracted features from segment 5368; Created a dataframe for segment 5368.
# Decomposed segment 5369; Extracted features from segment 5369; Created a dataframe for segment 5369.
# Decomposed segment 5370; Extracted features from segment 5370; Created a dataframe for segment 5370.
# Decomposed segment 5371; Extracted features from segment 5371; Created a dataframe for segment 5371.
# Decomposed segment 5372; Extracted features from segment 5372; Created a dataframe for segment 5372.
# Decomposed segment 5373; Extracted features from segment 5373; Created a dataframe for segment 5373.
# Decomposed segment 5374; Extracted features from segment 5374; Created a dataframe for segment 5374.
# Decomposed segment 5375; Extracted features from segment 5375; Created a dataframe for segment 5375.
# Decomposed segment 5376; Extracted features from segment 5376; Created a dataframe for segment 5376.
# Decomposed segment 5377; Extracted features from segment 5377; Created a dataframe for segment 5377.
# Decomposed segment 5378; Extracted features from segment 5378; Created a dataframe for segment 5378.
# Decomposed segment 5379; Extracted features from segment 5379; Created a dataframe for segment 5379.
# Decomposed segment 5380; Extracted features from segment 5380; Created a dataframe for segment 5380.
# Decomposed segment 5381; Extracted features from segment 5381; Created a dataframe for segment 5381.
# Decomposed segment 5382; Extracted features from segment 5382; Created a dataframe for segment 5382.
# Decomposed segment 5383; Extracted features from segment 5383; Created a dataframe for segment 5383.
# Decomposed segment 5384; Extracted features from segment 5384; Created a dataframe for segment 5384.
# Decomposed segment 5385; Extracted features from segment 5385; Created a dataframe for segment 5385.
# Decomposed segment 5386; Extracted features from segment 5386; Created a dataframe for segment 5386.
# Decomposed segment 5387; Extracted features from segment 5387; Created a dataframe for segment 5387.
# Decomposed segment 5388; Extracted features from segment 5388; Created a dataframe for segment 5388.
# Decomposed segment 5389; Extracted features from segment 5389; Created a dataframe for segment 5389.
# Decomposed segment 5390; Extracted features from segment 5390; Created a dataframe for segment 5390.
# Decomposed segment 5391; Extracted features from segment 5391; Created a dataframe for segment 5391.
# Decomposed segment 5392; Extracted features from segment 5392; Created a dataframe for segment 5392.
# Decomposed segment 5393; Extracted features from segment 5393; Created a dataframe for segment 5393.
# Decomposed segment 5394; Extracted features from segment 5394; Created a dataframe for segment 5394.
# Decomposed segment 5395; Extracted features from segment 5395; Created a dataframe for segment 5395.
# Decomposed segment 5396; Extracted features from segment 5396; Created a dataframe for segment 5396.
# Decomposed segment 5397; Extracted features from segment 5397; Created a dataframe for segment 5397.
# Decomposed segment 5398; Extracted features from segment 5398; Created a dataframe for segment 5398.
# Decomposed segment 5399; Extracted features from segment 5399; Created a dataframe for segment 5399.
# Decomposed segment 5400; Extracted features from segment 5400; Created a dataframe for segment 5400.
# Decomposed segment 5401; Extracted features from segment 5401; Created a dataframe for segment 5401.
# Decomposed segment 5402; Extracted features from segment 5402; Created a dataframe for segment 5402.
# Decomposed segment 5403; Extracted features from segment 5403; Created a dataframe for segment 5403.
# Decomposed segment 5404; Extracted features from segment 5404; Created a dataframe for segment 5404.
# Decomposed segment 5405; Extracted features from segment 5405; Created a dataframe for segment 5405.
# Decomposed segment 5406; Extracted features from segment 5406; Created a dataframe for segment 5406.
# Decomposed segment 5407; Extracted features from segment 5407; Created a dataframe for segment 5407.
# Decomposed segment 5408; Extracted features from segment 5408; Created a dataframe for segment 5408.
# Decomposed segment 5409; Extracted features from segment 5409; Created a dataframe for segment 5409.
# Decomposed segment 5410; Extracted features from segment 5410; Created a dataframe for segment 5410.
# Decomposed segment 5411; Extracted features from segment 5411; Created a dataframe for segment 5411.
# Decomposed segment 5412; Extracted features from segment 5412; Created a dataframe for segment 5412.
# Decomposed segment 5413; Extracted features from segment 5413; Created a dataframe for segment 5413.
# Decomposed segment 5414; Extracted features from segment 5414; Created a dataframe for segment 5414.
# Decomposed segment 5415; Extracted features from segment 5415; Created a dataframe for segment 5415.
# Decomposed segment 5416; Extracted features from segment 5416; Created a dataframe for segment 5416.
# Decomposed segment 5417; Extracted features from segment 5417; Created a dataframe for segment 5417.
# Decomposed segment 5418; Extracted features from segment 5418; Created a dataframe for segment 5418.
# Decomposed segment 5419; Extracted features from segment 5419; Created a dataframe for segment 5419.
# Decomposed segment 5420; Extracted features from segment 5420; Created a dataframe for segment 5420.
# Decomposed segment 5421; Extracted features from segment 5421; Created a dataframe for segment 5421.
# Decomposed segment 5422; Extracted features from segment 5422; Created a dataframe for segment 5422.
# Decomposed segment 5423; Extracted features from segment 5423; Created a dataframe for segment 5423.
# Decomposed segment 5424; Extracted features from segment 5424; Created a dataframe for segment 5424.
# Decomposed segment 5425; Extracted features from segment 5425; Created a dataframe for segment 5425.
# Decomposed segment 5426; Extracted features from segment 5426; Created a dataframe for segment 5426.
# Decomposed segment 5427; Extracted features from segment 5427; Created a dataframe for segment 5427.
# Decomposed segment 5428; Extracted features from segment 5428; Created a dataframe for segment 5428.
# Decomposed segment 5429; Extracted features from segment 5429; Created a dataframe for segment 5429.
# Decomposed segment 5430; Extracted features from segment 5430; Created a dataframe for segment 5430.
# Decomposed segment 5431; Extracted features from segment 5431; Created a dataframe for segment 5431.
# Decomposed segment 5432; Extracted features from segment 5432; Created a dataframe for segment 5432.
# Decomposed segment 5433; Extracted features from segment 5433; Created a dataframe for segment 5433.
# Decomposed segment 5434; Extracted features from segment 5434; Created a dataframe for segment 5434.
# Decomposed segment 5435; Extracted features from segment 5435; Created a dataframe for segment 5435.
# Decomposed segment 5436; Extracted features from segment 5436; Created a dataframe for segment 5436.
# Decomposed segment 5437; Extracted features from segment 5437; Created a dataframe for segment 5437.
# Decomposed segment 5438; Extracted features from segment 5438; Created a dataframe for segment 5438.
# Decomposed segment 5439; Extracted features from segment 5439; Created a dataframe for segment 5439.
# Decomposed segment 5440; Extracted features from segment 5440; Created a dataframe for segment 5440.
# Decomposed segment 5441; Extracted features from segment 5441; Created a dataframe for segment 5441.
# Decomposed segment 5442; Extracted features from segment 5442; Created a dataframe for segment 5442.
# Decomposed segment 5443; Extracted features from segment 5443; Created a dataframe for segment 5443.
# Decomposed segment 5444; Extracted features from segment 5444; Created a dataframe for segment 5444.
# Decomposed segment 5445; Extracted features from segment 5445; Created a dataframe for segment 5445.
# Decomposed segment 5446; Extracted features from segment 5446; Created a dataframe for segment 5446.
# Decomposed segment 5447; Extracted features from segment 5447; Created a dataframe for segment 5447.
# Decomposed segment 5448; Extracted features from segment 5448; Created a dataframe for segment 5448.
# Decomposed segment 5449; Extracted features from segment 5449; Created a dataframe for segment 5449.
# Decomposed segment 5450; Extracted features from segment 5450; Created a dataframe for segment 5450.
# Decomposed segment 5451; Extracted features from segment 5451; Created a dataframe for segment 5451.
# Decomposed segment 5452; Extracted features from segment 5452; Created a dataframe for segment 5452.
# Decomposed segment 5453; Extracted features from segment 5453; Created a dataframe for segment 5453.
# Decomposed segment 5454; Extracted features from segment 5454; Created a dataframe for segment 5454.
# Decomposed segment 5455; Extracted features from segment 5455; Created a dataframe for segment 5455.
# Decomposed segment 5456; Extracted features from segment 5456; Created a dataframe for segment 5456.
# Decomposed segment 5457; Extracted features from segment 5457; Created a dataframe for segment 5457.
# Decomposed segment 5458; Extracted features from segment 5458; Created a dataframe for segment 5458.
# Decomposed segment 5459; Extracted features from segment 5459; Created a dataframe for segment 5459.
# Decomposed segment 5460; Extracted features from segment 5460; Created a dataframe for segment 5460.
# Decomposed segment 5461; Extracted features from segment 5461; Created a dataframe for segment 5461.
# Decomposed segment 5462; Extracted features from segment 5462; Created a dataframe for segment 5462.
# Decomposed segment 5463; Extracted features from segment 5463; Created a dataframe for segment 5463.
# Decomposed segment 5464; Extracted features from segment 5464; Created a dataframe for segment 5464.
# Decomposed segment 5465; Extracted features from segment 5465; Created a dataframe for segment 5465.
# Decomposed segment 5466; Extracted features from segment 5466; Created a dataframe for segment 5466.
# Decomposed segment 5467; Extracted features from segment 5467; Created a dataframe for segment 5467.
# Decomposed segment 5468; Extracted features from segment 5468; Created a dataframe for segment 5468.
# Decomposed segment 5469; Extracted features from segment 5469; Created a dataframe for segment 5469.
# Decomposed segment 5470; Extracted features from segment 5470; Created a dataframe for segment 5470.
# Decomposed segment 5471; Extracted features from segment 5471; Created a dataframe for segment 5471.
# Decomposed segment 5472; Extracted features from segment 5472; Created a dataframe for segment 5472.
# Decomposed segment 5473; Extracted features from segment 5473; Created a dataframe for segment 5473.
# Decomposed segment 5474; Extracted features from segment 5474; Created a dataframe for segment 5474.
# Decomposed segment 5475; Extracted features from segment 5475; Created a dataframe for segment 5475.
# Decomposed segment 5476; Extracted features from segment 5476; Created a dataframe for segment 5476.
# ...
# Decomposed segment 9843; Extracted features from segment 9843; Created a dataframe for segment 9843.
# Decomposed segment 9844; Extracted features from segment 9844; Created a dataframe for segment 9844.
# Decomposed segment 9845; Extracted features from segment 9845; Created a dataframe for segment 9845.
# Decomposed segment 9846; Extracted features from segment 9846; Created a dataframe for segment 9846.
# Decomposed segment 9847; Extracted features from segment 9847; Created a dataframe for segment 9847.
# Decomposed segment 9848; Extracted features from segment 9848; Created a dataframe for segment 9848.
# Decomposed segment 9849; Extracted features from segment 9849; Created a dataframe for segment 9849.
# Decomposed segment 9850; Extracted features from segment 9850; Created a dataframe for segment 9850.
# Decomposed segment 9851; Extracted features from segment 9851; Created a dataframe for segment 9851.
# Decomposed segment 9852; Extracted features from segment 9852; Created a dataframe for segment 9852.
# Decomposed segment 9853; Extracted features from segment 9853; Created a dataframe for segment 9853.
# Decomposed segment 9854; Extracted features from segment 9854; Created a dataframe for segment 9854.
# Decomposed segment 9855; Extracted features from segment 9855; Created a dataframe for segment 9855.
# Decomposed segment 9856; Extracted features from segment 9856; Created a dataframe for segment 9856.
# Decomposed segment 9857; Extracted features from segment 9857; Created a dataframe for segment 9857.
# Decomposed segment 9858; Extracted features from segment 9858; Created a dataframe for segment 9858.
# Decomposed segment 9859; Extracted features from segment 9859; Created a dataframe for segment 9859.
# Decomposed segment 9860; Extracted features from segment 9860; Created a dataframe for segment 9860.
# Decomposed segment 9861; Extracted features from segment 9861; Created a dataframe for segment 9861.
# Decomposed segment 9862; Extracted features from segment 9862; Created a dataframe for segment 9862.
# Decomposed segment 9863; Extracted features from segment 9863; Created a dataframe for segment 9863.
# Decomposed segment 9864; Extracted features from segment 9864; Created a dataframe for segment 9864.
# Decomposed segment 9865; Extracted features from segment 9865; Created a dataframe for segment 9865.
# Decomposed segment 9866; Extracted features from segment 9866; Created a dataframe for segment 9866.
# Decomposed segment 9867; Extracted features from segment 9867; Created a dataframe for segment 9867.
# Decomposed segment 9868; Extracted features from segment 9868; Created a dataframe for segment 9868.
# Decomposed segment 9869; Extracted features from segment 9869; Created a dataframe for segment 9869.
# Decomposed segment 9870; Extracted features from segment 9870; Created a dataframe for segment 9870.
# Decomposed segment 9871; Extracted features from segment 9871; Created a dataframe for segment 9871.
# Decomposed segment 9872; Extracted features from segment 9872; Created a dataframe for segment 9872.
# Decomposed segment 9873; Extracted features from segment 9873; Created a dataframe for segment 9873.
# Decomposed segment 9874; Extracted features from segment 9874; Created a dataframe for segment 9874.
# Decomposed segment 9875; Extracted features from segment 9875; Created a dataframe for segment 9875.
# Decomposed segment 9876; Extracted features from segment 9876; Created a dataframe for segment 9876.
# Decomposed segment 9877; Extracted features from segment 9877; Created a dataframe for segment 9877.
# Decomposed segment 9878; Extracted features from segment 9878; Created a dataframe for segment 9878.
# Decomposed segment 9879; Extracted features from segment 9879; Created a dataframe for segment 9879.
# Decomposed segment 9880; Extracted features from segment 9880; Created a dataframe for segment 9880.
# Decomposed segment 9881; Extracted features from segment 9881; Created a dataframe for segment 9881.
# Decomposed segment 9882; Extracted features from segment 9882; Created a dataframe for segment 9882.
# Decomposed segment 9883; Extracted features from segment 9883; Created a dataframe for segment 9883.
# Decomposed segment 9884; Extracted features from segment 9884; Created a dataframe for segment 9884.
# Decomposed segment 9885; Extracted features from segment 9885; Created a dataframe for segment 9885.
# Decomposed segment 9886; Extracted features from segment 9886; Created a dataframe for segment 9886.
# Decomposed segment 9887; Extracted features from segment 9887; Created a dataframe for segment 9887.
# Decomposed segment 9888; Extracted features from segment 9888; Created a dataframe for segment 9888.
# Decomposed segment 9889; Extracted features from segment 9889; Created a dataframe for segment 9889.
# Decomposed segment 9890; Extracted features from segment 9890; Created a dataframe for segment 9890.
# Decomposed segment 9891; Extracted features from segment 9891; Created a dataframe for segment 9891.
# Decomposed segment 9892; Extracted features from segment 9892; Created a dataframe for segment 9892.
# Decomposed segment 9893; Extracted features from segment 9893; Created a dataframe for segment 9893.
# Decomposed segment 9894; Extracted features from segment 9894; Created a dataframe for segment 9894.
# Decomposed segment 9895; Extracted features from segment 9895; Created a dataframe for segment 9895.
# Decomposed segment 9896; Extracted features from segment 9896; Created a dataframe for segment 9896.
# Decomposed segment 9897; Extracted features from segment 9897; Created a dataframe for segment 9897.
# Decomposed segment 9898; Extracted features from segment 9898; Created a dataframe for segment 9898.
# Decomposed segment 9899; Extracted features from segment 9899; Created a dataframe for segment 9899.
# Decomposed segment 9900; Extracted features from segment 9900; Created a dataframe for segment 9900.
# Decomposed segment 9901; Extracted features from segment 9901; Created a dataframe for segment 9901.
# Decomposed segment 9902; Extracted features from segment 9902; Created a dataframe for segment 9902.
# Decomposed segment 9903; Extracted features from segment 9903; Created a dataframe for segment 9903.
# Decomposed segment 9904; Extracted features from segment 9904; Created a dataframe for segment 9904.
# Decomposed segment 9905; Extracted features from segment 9905; Created a dataframe for segment 9905.
# Decomposed segment 9906; Extracted features from segment 9906; Created a dataframe for segment 9906.
# Decomposed segment 9907; Extracted features from segment 9907; Created a dataframe for segment 9907.
# Decomposed segment 9908; Extracted features from segment 9908; Created a dataframe for segment 9908.
# Decomposed segment 9909; Extracted features from segment 9909; Created a dataframe for segment 9909.
# Decomposed segment 9910; Extracted features from segment 9910; Created a dataframe for segment 9910.
# Decomposed segment 9911; Extracted features from segment 9911; Created a dataframe for segment 9911.
# Decomposed segment 9912; Extracted features from segment 9912; Created a dataframe for segment 9912.
# Decomposed segment 9913; Extracted features from segment 9913; Created a dataframe for segment 9913.
# Decomposed segment 9914; Extracted features from segment 9914; Created a dataframe for segment 9914.
# Decomposed segment 9915; Extracted features from segment 9915; Created a dataframe for segment 9915.
# Decomposed segment 9916; Extracted features from segment 9916; Created a dataframe for segment 9916.
# Decomposed segment 9917; Extracted features from segment 9917; Created a dataframe for segment 9917.
# Decomposed segment 9918; Extracted features from segment 9918; Created a dataframe for segment 9918.
# Decomposed segment 9919; Extracted features from segment 9919; Created a dataframe for segment 9919.
# Decomposed segment 9920; Extracted features from segment 9920; Created a dataframe for segment 9920.
# Decomposed segment 9921; Extracted features from segment 9921; Created a dataframe for segment 9921.
# Decomposed segment 9922; Extracted features from segment 9922; Created a dataframe for segment 9922.
# Decomposed segment 9923; Extracted features from segment 9923; Created a dataframe for segment 9923.
# Decomposed segment 9924; Extracted features from segment 9924; Created a dataframe for segment 9924.
# Decomposed segment 9925; Extracted features from segment 9925; Created a dataframe for segment 9925.
# Decomposed segment 9926; Extracted features from segment 9926; Created a dataframe for segment 9926.
# Decomposed segment 9927; Extracted features from segment 9927; Created a dataframe for segment 9927.
# Decomposed segment 9928; Extracted features from segment 9928; Created a dataframe for segment 9928.
# Decomposed segment 9929; Extracted features from segment 9929; Created a dataframe for segment 9929.
# Decomposed segment 9930; Extracted features from segment 9930; Created a dataframe for segment 9930.
# Decomposed segment 9931; Extracted features from segment 9931; Created a dataframe for segment 9931.
# Decomposed segment 9932; Extracted features from segment 9932; Created a dataframe for segment 9932.
# Decomposed segment 9933; Extracted features from segment 9933; Created a dataframe for segment 9933.
# Decomposed segment 9934; Extracted features from segment 9934; Created a dataframe for segment 9934.
# Decomposed segment 9935; Extracted features from segment 9935; Created a dataframe for segment 9935.
# Decomposed segment 9936; Extracted features from segment 9936; Created a dataframe for segment 9936.
# Decomposed segment 9937; Extracted features from segment 9937; Created a dataframe for segment 9937.
# Decomposed segment 9938; Extracted features from segment 9938; Created a dataframe for segment 9938.
# Decomposed segment 9939; Extracted features from segment 9939; Created a dataframe for segment 9939.
# Decomposed segment 9940; Extracted features from segment 9940; Created a dataframe for segment 9940.
# Decomposed segment 9941; Extracted features from segment 9941; Created a dataframe for segment 9941.
# Decomposed segment 9942; Extracted features from segment 9942; Created a dataframe for segment 9942.
# Decomposed segment 9943; Extracted features from segment 9943; Created a dataframe for segment 9943.
# Decomposed segment 9944; Extracted features from segment 9944; Created a dataframe for segment 9944.
# Decomposed segment 9945; Extracted features from segment 9945; Created a dataframe for segment 9945.
# Decomposed segment 9946; Extracted features from segment 9946; Created a dataframe for segment 9946.
# Decomposed segment 9947; Extracted features from segment 9947; Created a dataframe for segment 9947.
# Decomposed segment 9948; Extracted features from segment 9948; Created a dataframe for segment 9948.
# Decomposed segment 9949; Extracted features from segment 9949; Created a dataframe for segment 9949.
# Decomposed segment 9950; Extracted features from segment 9950; Created a dataframe for segment 9950.
# Decomposed segment 9951; Extracted features from segment 9951; Created a dataframe for segment 9951.
# Decomposed segment 9952; Extracted features from segment 9952; Created a dataframe for segment 9952.
# Decomposed segment 9953; Extracted features from segment 9953; Created a dataframe for segment 9953.
# Decomposed segment 9954; Extracted features from segment 9954; Created a dataframe for segment 9954.
# Decomposed segment 9955; Extracted features from segment 9955; Created a dataframe for segment 9955.
# Decomposed segment 9956; Extracted features from segment 9956; Created a dataframe for segment 9956.
# Decomposed segment 9957; Extracted features from segment 9957; Created a dataframe for segment 9957.
# Decomposed segment 9958; Extracted features from segment 9958; Created a dataframe for segment 9958.
# Decomposed segment 9959; Extracted features from segment 9959; Created a dataframe for segment 9959.
# Decomposed segment 9960; Extracted features from segment 9960; Created a dataframe for segment 9960.
# Decomposed segment 9961; Extracted features from segment 9961; Created a dataframe for segment 9961.
# Decomposed segment 9962; Extracted features from segment 9962; Created a dataframe for segment 9962.
# Decomposed segment 9963; Extracted features from segment 9963; Created a dataframe for segment 9963.
# Decomposed segment 9964; Extracted features from segment 9964; Created a dataframe for segment 9964.
# Decomposed segment 9965; Extracted features from segment 9965; Created a dataframe for segment 9965.
# Decomposed segment 9966; Extracted features from segment 9966; Created a dataframe for segment 9966.
# Decomposed segment 9967; Extracted features from segment 9967; Created a dataframe for segment 9967.
# Decomposed segment 9968; Extracted features from segment 9968; Created a dataframe for segment 9968.
# Decomposed segment 9969; Extracted features from segment 9969; Created a dataframe for segment 9969.
# Decomposed segment 9970; Extracted features from segment 9970; Created a dataframe for segment 9970.
# Decomposed segment 9971; Extracted features from segment 9971; Created a dataframe for segment 9971.
# Decomposed segment 9972; Extracted features from segment 9972; Created a dataframe for segment 9972.
# Decomposed segment 9973; Extracted features from segment 9973; Created a dataframe for segment 9973.
# Decomposed segment 9974; Extracted features from segment 9974; Created a dataframe for segment 9974.
# Decomposed segment 9975; Extracted features from segment 9975; Created a dataframe for segment 9975.
# Decomposed segment 9976; Extracted features from segment 9976; Created a dataframe for segment 9976.
# Decomposed segment 9977; Extracted features from segment 9977; Created a dataframe for segment 9977.
# Decomposed segment 9978; Extracted features from segment 9978; Created a dataframe for segment 9978.
# Decomposed segment 9979; Extracted features from segment 9979; Created a dataframe for segment 9979.
# Decomposed segment 9980; Extracted features from segment 9980; Created a dataframe for segment 9980.
# Decomposed segment 9981; Extracted features from segment 9981; Created a dataframe for segment 9981.
# Decomposed segment 9982; Extracted features from segment 9982; Created a dataframe for segment 9982.
# Decomposed segment 9983; Extracted features from segment 9983; Created a dataframe for segment 9983.
# Decomposed segment 9984; Extracted features from segment 9984; Created a dataframe for segment 9984.
# Decomposed segment 9985; Extracted features from segment 9985; Created a dataframe for segment 9985.
# Decomposed segment 9986; Extracted features from segment 9986; Created a dataframe for segment 9986.
# Decomposed segment 9987; Extracted features from segment 9987; Created a dataframe for segment 9987.
# Decomposed segment 9988; Extracted features from segment 9988; Created a dataframe for segment 9988.
# Decomposed segment 9989; Extracted features from segment 9989; Created a dataframe for segment 9989.
# Decomposed segment 9990; Extracted features from segment 9990; Created a dataframe for segment 9990.
# Decomposed segment 9991; Extracted features from segment 9991; Created a dataframe for segment 9991.
# Decomposed segment 9992; Extracted features from segment 9992; Created a dataframe for segment 9992.
# Decomposed segment 9993; Extracted features from segment 9993; Created a dataframe for segment 9993.
# Decomposed segment 9994; Extracted features from segment 9994; Created a dataframe for segment 9994.
# Decomposed segment 9995; Extracted features from segment 9995; Created a dataframe for segment 9995.
# Decomposed segment 9996; Extracted features from segment 9996; Created a dataframe for segment 9996.
# Decomposed segment 9997; Extracted features from segment 9997; Created a dataframe for segment 9997.
# Decomposed segment 9998; Extracted features from segment 9998; Created a dataframe for segment 9998.
# Decomposed segment 9999; Extracted features from segment 9999; Created a dataframe for segment 9999.
# Decomposed segment 10000; Extracted features from segment 10000; Created a dataframe for segment 10000.
# Finished extracting features

# %%
print(train_features_df.shape)
# print(test_features_df.shape)
# Out:
# (10000, 13)

# %%
train_features_df.head()
# Out:
#        SE 1        CV 1      SV 1      BP 1      SE 2        CV 2      SV 2  \
# 0  0.053104  110.546819  2.806688  0.026258  0.118404   81.669821  5.301480
# 1  0.067027  149.100566  2.805306  0.026232  0.145470   34.975653  4.295432
# 2  0.160696   97.278659  0.715284  0.001705  0.182495  501.648071  1.171216
# 3  0.119019  100.465980  0.957592  0.003057  0.190198   34.040164  1.190192
# 4  0.070110   13.244190  6.957285  0.161346  0.227179   61.121371  7.160628
#
#        BP 2      SE 3        CV 3      SV 3      BP 3  Class
# 0  0.093686  0.084797    3.161368  8.032546  0.215073    0.0
# 1  0.061502  0.069384   17.030536  1.998322  0.013311    0.0
# 2  0.004572  0.175626    8.921380  0.538866  0.000968    0.0
# 3  0.004722  0.111292   17.490905  1.356022  0.006129    0.0
# 4  0.170915  0.134145  202.980582  5.641245  0.106079    0.0

# %%
# test_features_df.head()

# %%
# Remove rows where any cell has a NaN value
cleaned_train_df = train_features_df.dropna()
# cleaned_test_df = test_features_df.dropna()

print(cleaned_train_df.shape)
# print(cleaned_test_df.shape)
# Out:
# (9971, 13)

# %%
per_class = cleaned_train_df["Class"].value_counts()
print(per_class)
# Out:
# Class
# 0.0    2000
# 1.0    2000
# 2.0    2000
# 3.0    1998
# 4.0    1973
# Name: count, dtype: int64

# %%
# from sklearn import svm
# from sklearn.model_selection import cross_val_score, StratifiedKFold
# from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score
# from sklearn.preprocessing import StandardScaler
# from sklearn.pipeline import make_pipeline
# from imblearn.over_sampling import SMOTE
# from imblearn.pipeline import Pipeline as IMBPipeline

# # Scale data and set up the SVM with a cubic kernel
# pipeline = make_pipeline(StandardScaler(), svm.SVC(kernel='poly', degree=3, C=1.0, class_weight='balanced'))

# # Use SMOTE for oversampling if necessary
# smote_pipeline = IMBPipeline([
#     ('scaler', StandardScaler()),
#     ('smote', SMOTE(random_state=42)),
#     ('svm', svm.SVC(kernel='poly', degree=3, C=1.0, class_weight='balanced'))
# ])

# # Perform 10-fold cross-validation
# cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# try:
#     cv_scores = cross_val_score(pipeline, X_train, y_train, cv=cv, scoring='accuracy')
#     print("CV Scores without SMOTE: ", cv_scores)
#     print("Mean CV Accuracy without SMOTE: ", np.mean(cv_scores))
# except Exception as e:
#     print("Error during cross-validation without SMOTE: ", str(e))

# try:
#     cv_scores_smote = cross_val_score(smote_pipeline, X_train, y_train, cv=cv, scoring='accuracy')
#     print("CV Scores with SMOTE: ", cv_scores_smote)
#     print("Mean CV Accuracy with SMOTE: ", np.mean(cv_scores_smote))
# except Exception as e:
#     print("Error during cross-validation with SMOTE: ", str(e))

# # Choose the pipeline based on your assessment of class balance issues
# selected_pipeline = pipeline if np.mean(cv_scores) > np.mean(cv_scores_smote) else smote_pipeline

# # Train the model on the full training data and evaluate
# selected_pipeline.fit(X_train, y_train)
# y_pred = selected_pipeline.predict(X_test)

# # Calculate sensitivity, specificity, and accuracy
# cm = confusion_matrix(y_test, y_pred)
# sensitivity = recall_score(y_test, y_pred)
# specificity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
# accuracy = accuracy_score(y_test, y_pred)

# print("Test Sensitivity: ", sensitivity)
# print("Test Specificity: ", specificity)
# print("Test Accuracy: ", accuracy)

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score

# %%
# Separate features and labels
X_train = train_features_df.iloc[:, :-1]  # all columns except the last one
y_train = train_features_df.iloc[:, -1]   # the last column

X_test = test_features_df.iloc[:, :-1]  # all columns except the last one
y_test = test_features_df.iloc[:, -1]   # the last column

# %%
# Separate features and labels
X_train = train_features_df.iloc[:, :-1]  # all rows, all columns except the last
y_train = train_features_df.iloc[:, -1]   # all rows, last column

X_test = test_features_df.iloc[:, :-1]
y_test = test_features_df.iloc[:, -1]

# Create the SVM model with a cubic kernel
svm_model = SVC(kernel='poly', degree=3)

# Train the model
svm_model.fit(X_train, y_train)

# Optionally, evaluate the model on the test data
y_pred = svm_model.predict(X_test)
print("Accuracy on Test Data: ", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))

# %%
# # Fit model on the entire training data
# svm_model.fit(X_train, y_train)

# # Predict on the test data
# y_pred = svm_model.predict(X_test)

# # Compute metrics
# accuracy = accuracy_score(y_test, y_pred)
# conf_matrix = confusion_matrix(y_test, y_pred)
# sensitivity = recall_score(y_test, y_pred, pos_label=1)  # Assuming 1 is the positive class
# specificity = recall_score(y_test, y_pred, pos_label=0)  # Assuming 0 is the positive class

# print("Accuracy:", accuracy)
# print("Confusion Matrix:\n", conf_matrix)
# print("Sensitivity:", sensitivity)
# print("Specificity:", specificity)
