# %% [markdown]
# <a href="https://colab.research.google.com/github/Tharusha-Sihan/BSP-Paper-Implementation/blob/main/3EMD(0NaN)_FeatureVector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wfdb
# !pip install EMD-signal
# !pip install antropy

from google.colab import drive
drive.mount('/content/drive')

# !ls '/content/drive/MyDrive/BSP Paper Implementation/mit-bih-arrhythmia-database-1.0.0'
# Out:
# Collecting wfdb
#   Downloading wfdb-4.1.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb) (3.8.0)
# Requirement already satisfied: numpy>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.26.4)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (2.2.2)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from wfdb) (2.32.3)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->wfdb) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->wfdb) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (2024.8.30)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.16.0)
# Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: wfdb
# Successfully installed wfdb-4.1.2
# Collecting EMD-signal
#   Downloading EMD_signal-1.6.4-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.10/dist-packages (from EMD-signal) (1.26.4)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.10/dist-packages (from EMD-signal) (1.13.1)
# Collecting pathos>=0.2.1 (from EMD-signal)
#   Downloading pathos-0.3.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: tqdm<5.0,>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from EMD-signal) (4.66.6)
# Collecting ppft>=1.7.6.9 (from pathos>=0.2.1->EMD-signal)
#   Downloading ppft-1.7.6.9-py3-none-any.whl.metadata (12 kB)
# Collecting dill>=0.3.9 (from pathos>=0.2.1->EMD-signal)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Collecting pox>=0.3.5 (from pathos>=0.2.1->EMD-signal)
#   Downloading pox-0.3.5-py3-none-any.whl.metadata (8.0 kB)
# Collecting multiprocess>=0.70.17 (from pathos>=0.2.1->EMD-signal)
#   Downloading multiprocess-0.70.17-py310-none-any.whl.metadata (7.2 kB)
# Downloading EMD_signal-1.6.4-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.0 MB/s eta 0:00:00
# Downloading pathos-0.3.3-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 6.0 MB/s eta 0:00:00
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 9.3 MB/s eta 0:00:00
# Downloading multiprocess-0.70.17-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.2 MB/s eta 0:00:00
# Downloading pox-0.3.5-py3-none-any.whl (29 kB)
# Downloading ppft-1.7.6.9-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: ppft, pox, dill, multiprocess, pathos, EMD-signal
# Successfully installed EMD-signal-1.6.4 dill-0.3.9 multiprocess-0.70.17 pathos-0.3.3 pox-0.3.5 ppft-1.7.6.9
# Collecting antropy
#   Downloading antropy-0.1.6.tar.gz (17 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from antropy) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from antropy) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from antropy) (1.5.2)
# Requirement already satisfied: numba>=0.57 in /usr/local/lib/python3.10/dist-packages (from antropy) (0.60.0)
# Collecting stochastic (from antropy)
#   Downloading stochastic-0.7.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.57->antropy) (0.43.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->antropy) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->antropy) (3.5.0)
# Downloading stochastic-0.7.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 2.2 MB/s eta 0:00:00
# Building wheels for collected packages: antropy
#   Building wheel for antropy (pyproject.toml) ... done
#   Created wheel for antropy: filename=antropy-0.1.6-py3-none-any.whl size=16877 sha256=9c95eede4ef89ab6a426d34eaa1249d6743b4937a6c05fd453555a6a16960c72
#   Stored in directory: /root/.cache/pip/wheels/98/22/06/e91d7bb213c7133d5e2eb34258623e1e19928d5f05e1ee6812
# Successfully built antropy
# Installing collected packages: stochastic, antropy
# Successfully installed antropy-0.1.6 stochastic-0.7.0
# Mounted at /content/drive
# 100.atr    105.atr  111.atr  116.dat  122.atr  202.dat	209.at_  214.xws  221.xws  231.xws
# 100.dat    105.dat  111.dat  116.hea  122.dat  202.hea	209.atr  215.at_  222.at_  232.atr
# 100.hea    105.hea  111.hea  116.xws  122.hea  202.xws	209.dat  215.atr  222.atr  232.dat
# 100.xws    105.xws  111.xws  117.at_  122.xws  203.at-	209.hea  215.dat  222.dat  232.hea
# 101.atr    106.atr  112.atr  117.atr  123.atr  203.at_	209.xws  215.hea  222.hea  232.xws
# 101.dat    106.dat  112.dat  117.dat  123.dat  203.atr	210.atr  215.xws  222.xws  233.atr
# 101.hea    106.hea  112.hea  117.hea  123.hea  203.dat	210.dat  217.atr  223.atr  233.dat
# 101.xws    106.xws  112.xws  117.xws  123.xws  203.hea	210.hea  217.dat  223.dat  233.hea
# 102-0.atr  107.atr  113.atr  118.atr  124.atr  203.xws	210.xws  217.hea  223.hea  233.xws
# 102.atr    107.dat  113.dat  118.dat  124.dat  205.atr	212.atr  217.xws  223.xws  234.atr
# 102.dat    107.hea  113.hea  118.hea  124.hea  205.dat	212.dat  219.atr  228.atr  234.dat
# 102.hea    107.xws  113.xws  118.xws  124.xws  205.hea	212.hea  219.dat  228.dat  234.hea
# 102.xws    108.at_  114.atr  119.at_  200.atr  205.xws	212.xws  219.hea  228.hea  234.xws
# 103.atr    108.atr  114.dat  119.atr  200.dat  207.atr	213.atr  219.xws  228.xws  ANNOTATORS
# 103.dat    108.dat  114.hea  119.dat  200.hea  207.dat	213.dat  220.atr  230.atr  mitdbdir
# 103.hea    108.hea  114.xws  119.hea  200.xws  207.hea	213.hea  220.dat  230.dat  RECORDS
# 103.xws    108.xws  115.atr  119.xws  201.atr  207.xws	213.xws  220.hea  230.hea  SHA256SUMS.txt
# 104.atr    109.atr  115.dat  121.atr  201.dat  208.atr	214.at_  220.xws  230.xws  x_mitdb
# 104.dat    109.dat  115.hea  121.dat  201.hea  208.dat	214.atr  221.atr  231.atr
# 104.hea    109.hea  115.xws  121.hea  201.xws  208.hea	214.dat  221.dat  231.dat
# 104.xws    109.xws  116.atr  121.xws  202.atr  208.xws	214.hea  221.hea  231.hea

# %%
import os
import wfdb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.signal as sg
import antropy as ant
import math

from numpy.linalg import svd
from scipy import stats
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split
from PyEMD import EMD, EEMD
# from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor

# Define the path to the dataset directory in your Google Drive
path = '/content/drive/MyDrive/BSP Paper Implementation/mit-bih-arrhythmia-database-1.0.0/'

# %%
# Define parameters

SEGMENT_SIZE = 300
TRAIN_SET_SIZE = 2000
TEST_SET_SIZE = 500

# EMD and EEMD parameters
EMD_IMFS = 3
EEMD_IMFS = 7

# %%
#### Function definitions

## Preprocessing

# Mean bias correction
def bias_correction(signal):
    return signal - np.mean(signal)

# Moving average filter with ceiling phase shift compensation
def MA_filter(signal, window_size=6):
    # Apply the moving average filter
    filtered_signal = np.convolve(signal, np.ones(window_size) / window_size, mode='valid')

    # Calculate the phase shift (ceiling of half the window size)
    phase_shift = math.ceil((window_size - 1) / 2)

    # Compensate for the phase shift by padding the filtered signal
    compensated_signal = np.pad(filtered_signal, (phase_shift, 0), mode='edge')

    return compensated_signal

# High pass filter
def HP_filter(signal, cutoff=1, fs=360, order=6):
    nyquist = 0.5 * fs  # Nyquist frequency
    normal_cutoff = cutoff / nyquist  # Normalize the cutoff frequency
    b, a = sg.butter(order, normal_cutoff, btype='high', analog=False)  # Butterworth filter
    filtered_signal = sg.filtfilt(b, a, signal)  # Apply filter
    return filtered_signal

# Low pass filter
def LP_filter(signal, cutoff=45, fs=360, order=5):
    nyquist = 0.5 * fs  # Nyquist frequency
    normal_cutoff = cutoff / nyquist  # Normalize the cutoff frequency
    b, a = sg.butter(order, normal_cutoff, btype='low', analog=False)  # Butterworth filter
    filtered_signal = sg.filtfilt(b, a, signal)  # forward backward filtering
    return filtered_signal

# Denoising
def denoise(signal):
    stage1 = bias_correction(signal)
    stage2 = MA_filter(stage1)
    stage3 = HP_filter(stage2)
    stage4 = LP_filter(stage3)
    return stage4

## Feature extraction

# Initializing EMD
emd = EMD(spline_kind = "cubic", std_thr = 0.3, total_power_thr = 0.0005, range_thr = 0.0001)

# Initializing EEMD
eemd = EEMD()

# Extracting the feature vector from a set of IMFs
def extract_features(IMFs):
    # Combine all features into a feature vector
    feature_vector = []
    column_names = []
    i = 0
    for imf in IMFs:
        i = i + 1

        # Perform SVD and extract singular value (SV)
        singular_value = svd(imf.reshape(-1, 1), compute_uv=False)[0]

        # Calculate Coefficient of Variation (CV)
        mean_imf = np.mean(imf)
        std_imf = np.std(imf)
        CV = (std_imf / mean_imf) ** 2

        # Calculate Sample Entropy (SEN)
        sampEn = ant.sample_entropy(imf)

        # Calculate Band Power (BP)
        bp_value = np.mean(np.square(imf))

        features = [sampEn, CV, singular_value, bp_value]
        columns = [f'SV {i}', f'CV {i}', f'SEN {i}', f'BP {i}']
        feature_vector = np.concatenate((feature_vector, features))
        column_names = np.concatenate((column_names, columns))
    column_names = np.concatenate((column_names, ["Class"]))
    return feature_vector, column_names

# Extracting features data fram from an input dataframe
def get_features_df(input_df, decompose):
    print("Started extracting features")
    all_features_df = pd.DataFrame()
    # print(all_features_df.shape)
    for i in range(input_df.shape[0]):
        X_i = input_df.iloc[i, :-1].to_numpy()
        y_i = input_df.iloc[i,-1]

        if (decompose == "eemd"):
            IMFs = eemd (X_i, max_imf = EEMD_IMFS)
            if (len(IMFs)>EEMD_IMFS):
                IMFs = IMFs[0:EEMD_IMFS]

        elif (decompose == "emd"):
            IMFs = emd(X_i, max_imf = EMD_IMFS)
            if (len(IMFs)>EMD_IMFS):
                IMFs = IMFs[0:EMD_IMFS]

        else:
            print(f"Error: Invalid decomposition method '{decompose}' provided")
            break
        if (i+1) % 100 == 0: print(f"Decomposed segment {i+1}", end='; ')

        features_i, column_names = extract_features(IMFs)
        if (i+1) % 100 == 0: print(f"Extracted features from segment {i+1}", end='; ')
        features_i = np.append(features_i, y_i)
        feature_df = pd.DataFrame([features_i], columns=column_names)
        if (i+1) % 100 == 0: print(f"Created a dataframe for segment {i+1}.")
        all_features_df = pd.concat([all_features_df, feature_df], ignore_index=True)

    print("Finished extracting features")
    print() # Print an empty space
    return all_features_df

# %%
# Segment size
window_size = SEGMENT_SIZE

# Define arrhythmia classes
classes = ['N', 'V', 'A', 'L', 'R']  # Normal, Ventricular Premature (VP), Atrial Premature (AP), Left Bundle Branch Block (LBBB), Right Bundle Branch Block (RBBB)
n_classes = len(classes)
count_classes = [0] * n_classes

# Initialize lists to store beats and labels
X = list()
y = list()

# Fetch record files from the dataset directory
filenames = next(os.walk(path))[2]
filenames.sort()

# Process each record and annotation
for filename in filenames:
    example_beat_printed = False
    # Only process .dat files (the signal data files)
    if filename.endswith('.dat'):
        record_name = filename.split('.')[0]

        # Read the record (signals) and annotations
        if record_name == '114':  # MLII is channel 1 not 0
            record = wfdb.rdrecord((path + record_name), channels=[1])
        else:
            record = wfdb.rdrecord((path + record_name), channels=[0])

        annotation = wfdb.rdann(path + record_name, 'atr')

        signals_original = record.p_signal[:, 0]  # Taking MLII
        signals = denoise(signals_original)

        # Process the annotations to extract beats
        for i in range(len(annotation.sample)):
            arrhythmia_type = annotation.symbol[i]

            # Plot an example to the signals
            if i == 1 and record_name == '101':
                # Plot each patient's signal
                plt.figure(figsize=(12, 3))
                plt.title(f"700 Datapoints From Record {record_name} Wave")
                plt.plot(signals[0:700])
                plt.grid(True)
                plt.show()

            if arrhythmia_type in classes:
                arrhythmia_index = classes.index(arrhythmia_type)
                pos = annotation.sample[i]  # Position of the R-peak (sample index)

                # Ensure we don't go out of bounds when extracting the beat
                if window_size//2 <= pos < len(signals) - window_size//2:
                    beat = signals[pos-window_size//2:pos+window_size//2]
                    beat = stats.zscore(beat)  # Z-score normalization
                    beat = beat/ np.max(np.abs(beat)) # Unity scaling

                    # Plot an example beat (once)
                    if record_name == '101' and not example_beat_printed:
                        print() # Print an empty space before figure
                        plt.figure(figsize=(6, 3))
                        plt.title(f"A Single Beat From Record {record_name} Wave")
                        plt.plot(beat)
                        plt.grid(True)
                        plt.show()
                        example_beat_printed = True

                    X.append(beat)  # 300 point ECG vectors
                    y.append(arrhythmia_index)  # Arrhythmia class labels
                    count_classes[arrhythmia_index] += 1

print() # Print an empty space
print(np.shape(X), np.shape(y))
print("Class distribution:", count_classes)
# Out:
# (100017, 300) (100017,)
# Class distribution: [75016, 7129, 2546, 8071, 7255]

# %%
pos = annotation.sample[3]  # Position of the R-peak (sample index)

if window_size//2 <= pos < len(signals_original) - window_size//2:
  beat_original = signals_original[pos-window_size//2:pos+window_size//2]
  beat_original = stats.zscore(beat_original)  # Z-score normalization
  beat_original = beat_original/ np.max(np.abs(beat_original)) # Unity scaling

  beat = signals[pos-window_size//2:pos+window_size//2]
  beat = stats.zscore(beat)  # Z-score normalization
  beat = beat/ np.max(np.abs(beat)) # Unity scaling

fig, axs = plt.subplots(1, 2, figsize=(12, 4))  # Create a figure with 1 row and 2 columns
# fig.suptitle("ECG Waveforms")  # Add a common title for both plots

# Plot the original ECG waveform
axs[0].set_title("Original ECG Waveform")
axs[0].plot(beat_original)
axs[0].grid(True)

# Plot the denoised ECG waveform
axs[1].set_title("Denoised ECG Waveform")
axs[1].plot(beat)
axs[1].grid(True)

# Display the plots
plt.tight_layout()  # Adjust layout to fit titles and labels
plt.show()

# %%
# Creating a data frame
X_df = pd.DataFrame(X)
X_df[len(X[0])] = y
X_df.shape
# Out:
# (100017, 301)

# %%
# Distribution of data
per_class = X_df[X_df.shape[1]-1].value_counts()
print(per_class)

plt.figure(figsize=(7,7))
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(per_class, labels=['N', 'L', 'R', 'V', 'A'], colors=['tab:blue','tab:orange','tab:purple','tab:olive','tab:green'],autopct='%1.1f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()
# Out:
# 300
# 0    75016
# 3     8071
# 4     7255
# 1     7129
# 2     2546
# Name: count, dtype: int64

# %%
# Resampling the dataset to get to an even distribution
# TEST_SET_SIZE test data and TRAIN_SET_SIZE training data from each class
n_train = TRAIN_SET_SIZE
n_test = TEST_SET_SIZE
n_total = n_train + n_test

test_ratio = n_test/(n_total)

train = pd.DataFrame()
test = pd.DataFrame()

for class_value in range(5):

    # Filter the dataframe for the current class
    df_class = X_df[X_df[300] == class_value]

    # Randomly sample 2500 rows (or all rows if less )
    df_sampled_class = df_class.sample(n=min(n_total, len(df_class)), random_state=42)

    train_class, test_class = train_test_split(df_sampled_class, test_size= test_ratio)

    # Append the sampled rows to the new dataframe
    train = pd.concat([train, train_class])
    test = pd.concat([test, test_class])

# Reset index of the new dataframe
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

# Display the new dataframe
train.shape, test.shape
# Out:
# ((10000, 301), (2500, 301))

# %%
per_class = train[train.shape[1]-1].value_counts()
print(per_class)
# Out:
# 300
# 0    2000
# 1    2000
# 2    2000
# 3    2000
# 4    2000
# Name: count, dtype: int64

# %%
# Execute EEMD on signal
IMFs = emd(X[0], max_imf=EMD_IMFS)
N = IMFs.shape[0] # Number of subplots

plt.figure(figsize=(10, 2*(N+1)))  # Adjust the height based on the number of IMFs

# Plot the input signal
plt.subplot(N+1, 1, 1)
plt.plot(X[0], "r")
plt.title("Input Signal: X[0]")
plt.grid(True)

# Plot each IMF
for n, imf in enumerate(IMFs[:]):
    plt.subplot(N+1, 1, n + 2)
    plt.plot(imf, "g")
    plt.title(f"IMF {n + 1}")
    plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %%
train_features_df = get_features_df(train, "emd")
test_features_df = get_features_df(test, "emd")
# Out:
# Started extracting features
# Decomposed segment 100; Extracted features from segment 100; Created a dataframe for segment 100.
# Decomposed segment 200; Extracted features from segment 200; Created a dataframe for segment 200.
# Decomposed segment 300; Extracted features from segment 300; Created a dataframe for segment 300.
# Decomposed segment 400; Extracted features from segment 400; Created a dataframe for segment 400.
# Decomposed segment 500; Extracted features from segment 500; Created a dataframe for segment 500.
# Decomposed segment 600; Extracted features from segment 600; Created a dataframe for segment 600.
# Decomposed segment 700; Extracted features from segment 700; Created a dataframe for segment 700.
# Decomposed segment 800; Extracted features from segment 800; Created a dataframe for segment 800.
# Decomposed segment 900; Extracted features from segment 900; Created a dataframe for segment 900.
# Decomposed segment 1000; Extracted features from segment 1000; Created a dataframe for segment 1000.
# Decomposed segment 1100; Extracted features from segment 1100; Created a dataframe for segment 1100.
# Decomposed segment 1200; Extracted features from segment 1200; Created a dataframe for segment 1200.
# Decomposed segment 1300; Extracted features from segment 1300; Created a dataframe for segment 1300.
# Decomposed segment 1400; Extracted features from segment 1400; Created a dataframe for segment 1400.
# Decomposed segment 1500; Extracted features from segment 1500; Created a dataframe for segment 1500.
# Decomposed segment 1600; Extracted features from segment 1600; Created a dataframe for segment 1600.
# Decomposed segment 1700; Extracted features from segment 1700; Created a dataframe for segment 1700.
# Decomposed segment 1800; Extracted features from segment 1800; Created a dataframe for segment 1800.
# Decomposed segment 1900; Extracted features from segment 1900; Created a dataframe for segment 1900.
# Decomposed segment 2000; Extracted features from segment 2000; Created a dataframe for segment 2000.
# Decomposed segment 2100; Extracted features from segment 2100; Created a dataframe for segment 2100.
# Decomposed segment 2200; Extracted features from segment 2200; Created a dataframe for segment 2200.
# Decomposed segment 2300; Extracted features from segment 2300; Created a dataframe for segment 2300.
# Decomposed segment 2400; Extracted features from segment 2400; Created a dataframe for segment 2400.
# Decomposed segment 2500; Extracted features from segment 2500; Created a dataframe for segment 2500.
# Decomposed segment 2600; Extracted features from segment 2600; Created a dataframe for segment 2600.
# Decomposed segment 2700; Extracted features from segment 2700; Created a dataframe for segment 2700.
# Decomposed segment 2800; Extracted features from segment 2800; Created a dataframe for segment 2800.
# Decomposed segment 2900; Extracted features from segment 2900; Created a dataframe for segment 2900.
# Decomposed segment 3000; Extracted features from segment 3000; Created a dataframe for segment 3000.
# Decomposed segment 3100; Extracted features from segment 3100; Created a dataframe for segment 3100.
# Decomposed segment 3200; Extracted features from segment 3200; Created a dataframe for segment 3200.
# Decomposed segment 3300; Extracted features from segment 3300; Created a dataframe for segment 3300.
# Decomposed segment 3400; Extracted features from segment 3400; Created a dataframe for segment 3400.
# Decomposed segment 3500; Extracted features from segment 3500; Created a dataframe for segment 3500.
# Decomposed segment 3600; Extracted features from segment 3600; Created a dataframe for segment 3600.
# Decomposed segment 3700; Extracted features from segment 3700; Created a dataframe for segment 3700.
# Decomposed segment 3800; Extracted features from segment 3800; Created a dataframe for segment 3800.
# Decomposed segment 3900; Extracted features from segment 3900; Created a dataframe for segment 3900.
# Decomposed segment 4000; Extracted features from segment 4000; Created a dataframe for segment 4000.
# Decomposed segment 4100; Extracted features from segment 4100; Created a dataframe for segment 4100.
# Decomposed segment 4200; Extracted features from segment 4200; Created a dataframe for segment 4200.
# Decomposed segment 4300; Extracted features from segment 4300; Created a dataframe for segment 4300.
# Decomposed segment 4400; Extracted features from segment 4400; Created a dataframe for segment 4400.
# Decomposed segment 4500; Extracted features from segment 4500; Created a dataframe for segment 4500.
# Decomposed segment 4600; Extracted features from segment 4600; Created a dataframe for segment 4600.
# Decomposed segment 4700; Extracted features from segment 4700; Created a dataframe for segment 4700.
# Decomposed segment 4800; Extracted features from segment 4800; Created a dataframe for segment 4800.
# Decomposed segment 4900; Extracted features from segment 4900; Created a dataframe for segment 4900.
# Decomposed segment 5000; Extracted features from segment 5000; Created a dataframe for segment 5000.
# Decomposed segment 5100; Extracted features from segment 5100; Created a dataframe for segment 5100.
# Decomposed segment 5200; Extracted features from segment 5200; Created a dataframe for segment 5200.
# Decomposed segment 5300; Extracted features from segment 5300; Created a dataframe for segment 5300.
# Decomposed segment 5400; Extracted features from segment 5400; Created a dataframe for segment 5400.
# Decomposed segment 5500; Extracted features from segment 5500; Created a dataframe for segment 5500.
# Decomposed segment 5600; Extracted features from segment 5600; Created a dataframe for segment 5600.
# Decomposed segment 5700; Extracted features from segment 5700; Created a dataframe for segment 5700.
# Decomposed segment 5800; Extracted features from segment 5800; Created a dataframe for segment 5800.
# Decomposed segment 5900; Extracted features from segment 5900; Created a dataframe for segment 5900.
# Decomposed segment 6000; Extracted features from segment 6000; Created a dataframe for segment 6000.
# Decomposed segment 6100; Extracted features from segment 6100; Created a dataframe for segment 6100.
# Decomposed segment 6200; Extracted features from segment 6200; Created a dataframe for segment 6200.
# Decomposed segment 6300; Extracted features from segment 6300; Created a dataframe for segment 6300.
# Decomposed segment 6400; Extracted features from segment 6400; Created a dataframe for segment 6400.
# Decomposed segment 6500; Extracted features from segment 6500; Created a dataframe for segment 6500.
# Decomposed segment 6600; Extracted features from segment 6600; Created a dataframe for segment 6600.
# Decomposed segment 6700; Extracted features from segment 6700; Created a dataframe for segment 6700.
# Decomposed segment 6800; Extracted features from segment 6800; Created a dataframe for segment 6800.
# Decomposed segment 6900; Extracted features from segment 6900; Created a dataframe for segment 6900.
# Decomposed segment 7000; Extracted features from segment 7000; Created a dataframe for segment 7000.
# Decomposed segment 7100; Extracted features from segment 7100; Created a dataframe for segment 7100.
# Decomposed segment 7200; Extracted features from segment 7200; Created a dataframe for segment 7200.
# Decomposed segment 7300; Extracted features from segment 7300; Created a dataframe for segment 7300.
# Decomposed segment 7400; Extracted features from segment 7400; Created a dataframe for segment 7400.
# Decomposed segment 7500; Extracted features from segment 7500; Created a dataframe for segment 7500.
# Decomposed segment 7600; Extracted features from segment 7600; Created a dataframe for segment 7600.
# Decomposed segment 7700; Extracted features from segment 7700; Created a dataframe for segment 7700.
# Decomposed segment 7800; Extracted features from segment 7800; Created a dataframe for segment 7800.
# Decomposed segment 7900; Extracted features from segment 7900; Created a dataframe for segment 7900.
# Decomposed segment 8000; Extracted features from segment 8000; Created a dataframe for segment 8000.
# Decomposed segment 8100; Extracted features from segment 8100; Created a dataframe for segment 8100.
# Decomposed segment 8200; Extracted features from segment 8200; Created a dataframe for segment 8200.
# Decomposed segment 8300; Extracted features from segment 8300; Created a dataframe for segment 8300.
# Decomposed segment 8400; Extracted features from segment 8400; Created a dataframe for segment 8400.
# Decomposed segment 8500; Extracted features from segment 8500; Created a dataframe for segment 8500.
# Decomposed segment 8600; Extracted features from segment 8600; Created a dataframe for segment 8600.
# Decomposed segment 8700; Extracted features from segment 8700; Created a dataframe for segment 8700.
# Decomposed segment 8800; Extracted features from segment 8800; Created a dataframe for segment 8800.
# Decomposed segment 8900; Extracted features from segment 8900; Created a dataframe for segment 8900.
# Decomposed segment 9000; Extracted features from segment 9000; Created a dataframe for segment 9000.
# Decomposed segment 9100; Extracted features from segment 9100; Created a dataframe for segment 9100.
# Decomposed segment 9200; Extracted features from segment 9200; Created a dataframe for segment 9200.
# Decomposed segment 9300; Extracted features from segment 9300; Created a dataframe for segment 9300.
# Decomposed segment 9400; Extracted features from segment 9400; Created a dataframe for segment 9400.
# Decomposed segment 9500; Extracted features from segment 9500; Created a dataframe for segment 9500.
# Decomposed segment 9600; Extracted features from segment 9600; Created a dataframe for segment 9600.
# Decomposed segment 9700; Extracted features from segment 9700; Created a dataframe for segment 9700.
# Decomposed segment 9800; Extracted features from segment 9800; Created a dataframe for segment 9800.
# Decomposed segment 9900; Extracted features from segment 9900; Created a dataframe for segment 9900.
# Decomposed segment 10000; Extracted features from segment 10000; Created a dataframe for segment 10000.
# Finished extracting features
#
# Started extracting features
# Decomposed segment 100; Extracted features from segment 100; Created a dataframe for segment 100.
# Decomposed segment 200; Extracted features from segment 200; Created a dataframe for segment 200.
# Decomposed segment 300; Extracted features from segment 300; Created a dataframe for segment 300.
# Decomposed segment 400; Extracted features from segment 400; Created a dataframe for segment 400.
# Decomposed segment 500; Extracted features from segment 500; Created a dataframe for segment 500.
# Decomposed segment 600; Extracted features from segment 600; Created a dataframe for segment 600.
# Decomposed segment 700; Extracted features from segment 700; Created a dataframe for segment 700.
# Decomposed segment 800; Extracted features from segment 800; Created a dataframe for segment 800.
# Decomposed segment 900; Extracted features from segment 900; Created a dataframe for segment 900.
# Decomposed segment 1000; Extracted features from segment 1000; Created a dataframe for segment 1000.
# Decomposed segment 1100; Extracted features from segment 1100; Created a dataframe for segment 1100.
# Decomposed segment 1200; Extracted features from segment 1200; Created a dataframe for segment 1200.
# Decomposed segment 1300; Extracted features from segment 1300; Created a dataframe for segment 1300.
# Decomposed segment 1400; Extracted features from segment 1400; Created a dataframe for segment 1400.
# Decomposed segment 1500; Extracted features from segment 1500; Created a dataframe for segment 1500.
# Decomposed segment 1600; Extracted features from segment 1600; Created a dataframe for segment 1600.
# Decomposed segment 1700; Extracted features from segment 1700; Created a dataframe for segment 1700.
# Decomposed segment 1800; Extracted features from segment 1800; Created a dataframe for segment 1800.
# Decomposed segment 1900; Extracted features from segment 1900; Created a dataframe for segment 1900.
# Decomposed segment 2000; Extracted features from segment 2000; Created a dataframe for segment 2000.
# Decomposed segment 2100; Extracted features from segment 2100; Created a dataframe for segment 2100.
# Decomposed segment 2200; Extracted features from segment 2200; Created a dataframe for segment 2200.
# Decomposed segment 2300; Extracted features from segment 2300; Created a dataframe for segment 2300.
# Decomposed segment 2400; Extracted features from segment 2400; Created a dataframe for segment 2400.
# Decomposed segment 2500; Extracted features from segment 2500; Created a dataframe for segment 2500.
# Finished extracting features

# %%
print(train_features_df.shape)
print(test_features_df.shape)
# Out:
# (10000, 13)
# (2500, 13)

# %%
train_features_df.head()
# Out:
#        SV 1          CV 1     SEN 1      BP 1      SV 2        CV 2     SEN 2  \
# 0  0.136669    363.075995  2.620880  0.022897  0.194258  214.118963  1.632349
# 1  0.014734    608.949030  2.235055  0.016652  0.094644   83.621573  2.821206
# 2  0.086510    145.739821  2.040810  0.013883  0.233270   29.569511  2.154498
# 3  0.087918     76.688169  2.521422  0.021192  0.274738  115.836753  2.565009
# 4  0.041513  18568.139973  2.138526  0.015244  0.086452   13.253548  4.519300
#
#        BP 2      SV 3        CV 3     SEN 3      BP 3  Class
# 0  0.008882  0.218826  467.128029  2.011277  0.013484    0.0
# 1  0.026531  0.060395    4.238636  1.741788  0.010113    0.0
# 2  0.015473  0.150270   73.227654  1.930951  0.012429    0.0
# 3  0.021931  0.084266    6.030983  3.087817  0.031782    0.0
# 4  0.068080  0.067664    9.939957  2.260029  0.017026    0.0

# %%
test_features_df.head()
# Out:
#        SV 1        CV 1     SEN 1      BP 1      SV 2         CV 2     SEN 2  \
# 0  0.151251   37.398521  2.923841  0.028496  0.187721  2945.012805  4.381076
# 1  0.181232   43.756205  2.130722  0.015133  0.239390  7959.048770  2.598538
# 2  0.018604  727.807503  1.380153  0.006349  0.079328  3613.389090  2.262627
# 3  0.025950  327.285532  3.427147  0.039151  0.165180  3341.863662  4.355456
# 4  0.025821   32.910277  2.972440  0.029451  0.132631    92.665380  2.431395
#
#        BP 2      SV 3         CV 3     SEN 3      BP 3  Class
# 0  0.063979  0.097123    75.474488  1.951389  0.012693    0.0
# 1  0.022508  0.107375    23.840514  2.011034  0.013481    0.0
# 2  0.017065  0.118098    79.454240  1.780417  0.010566    0.0
# 3  0.063233  0.115747  1976.916702  2.449024  0.019992    0.0
# 4  0.019706  0.158467  3601.448182  1.986483  0.013154    0.0

# %%
# Adjusted rows where any cell has a NaN value to replace it with a 0
adjusted_train_df = train_features_df.fillna(0)
adjusted_test_df = test_features_df.fillna(0)

# %%
print(adjusted_train_df.shape)
# Out:
# (10000, 13)

# %%
print(adjusted_test_df.shape)
# Out:
# (2500, 13)

# %%
per_class_train = adjusted_train_df["Class"].value_counts()
print(per_class_train)
# Out:
# Class
# 0.0    2000
# 1.0    2000
# 2.0    2000
# 3.0    2000
# 4.0    2000
# Name: count, dtype: int64

# %%
per_class_test = adjusted_test_df["Class"].value_counts()
print(per_class_test)
# Out:
# Class
# 0.0    500
# 1.0    500
# 2.0    500
# 3.0    500
# 4.0    500
# Name: count, dtype: int64

# %%
# Set the display options
pd.set_option('display.max_rows', None)  # This line will allow all rows to be displayed.
pd.set_option('display.max_columns', None)  # This line will allow all columns to be displayed.
pd.set_option('display.width', None)  # This ensures that the display width is adjusted to show each line completely.

# Create an empty DataFrame with specified columns
columns = ['Features', 'Normal', 'PVC', 'APC', 'LBBB', 'RBBB']  # Example column names
feature_stats = pd.DataFrame(index=range((EMD_IMFS*4)+1), columns=columns)

for class_label in range(5):  # Looping through classes 0 to 4
    # Filter the dataframe for the current class
    class_df = adjusted_train_df[adjusted_train_df['Class'] == class_label]

    # Calculate the median
    median = class_df['Class'].median()

    # Calculate Q1 and Q3
    Q1 = class_df['Class'].quantile(0.25)
    Q3 = class_df['Class'].quantile(0.75)

    # Calculate IQR
    IQR = Q3 - Q1

    feature_stats.iat[0, 0] = 'Class'
    feature_stats.iat[0, class_label+1] = f"{median:.5f} ± {IQR/2:.5f}"

    i = 1

    for column in class_df.columns[:-1]:
      if column != 'Class':
        # Calculate the median
        median = class_df[column].median()

        # Calculate Q1 and Q3
        Q1 = class_df[column].quantile(0.25)
        Q3 = class_df[column].quantile(0.75)

        # Calculate IQR
        IQR = Q3 - Q1

        feature_stats.iat[i, 0] = column
        feature_stats.iat[i, class_label+1] = f"{median:.5f} ± {IQR/2:.5f}"
        i = i + 1

feature_stats
# Out:
#    Features                 Normal                   PVC                    APC  \
# 0     Class      0.00000 ± 0.00000     1.00000 ± 0.00000      2.00000 ± 0.00000
# 1      SV 1      0.05115 ± 0.02880     0.10878 ± 0.05595      0.10930 ± 0.05407
# 2      CV 1  117.85408 ± 273.38004  99.91216 ± 224.21411  162.47909 ± 333.52198
# 3     SEN 1      2.24835 ± 0.46653     2.35483 ± 0.88387      2.20180 ± 0.34633
# 4      BP 1      0.01685 ± 0.00702     0.01848 ± 0.01482      0.01616 ± 0.00531
# 5      SV 2      0.13847 ± 0.03875     0.14040 ± 0.04193      0.20164 ± 0.04534
# 6      CV 2  127.32276 ± 262.48095  49.07276 ± 128.67144  266.85989 ± 523.66415
# 7     SEN 2      2.65945 ± 0.55835     4.47684 ± 1.37104      2.79281 ± 0.55147
# 8      BP 2      0.02358 ± 0.01048     0.06681 ± 0.04056      0.02600 ± 0.01076
# 9      SV 3      0.12073 ± 0.03743     0.06895 ± 0.02501      0.13769 ± 0.03210
# 10     CV 3    37.28439 ± 81.08131   14.09494 ± 31.14557    28.49787 ± 90.01813
# 11    SEN 3      2.21263 ± 0.55082     3.17399 ± 0.96896      2.55379 ± 0.60456
# 12     BP 3      0.01632 ± 0.00809     0.03358 ± 0.02071      0.02174 ± 0.01010
#
#                     LBBB                   RBBB
# 0      3.00000 ± 0.00000      4.00000 ± 0.00000
# 1      0.06903 ± 0.01777      0.05060 ± 0.02606
# 2    55.61905 ± 87.04476  198.35297 ± 356.37543
# 3      2.74030 ± 0.74497      2.59556 ± 0.76901
# 4      0.02503 ± 0.01307      0.02246 ± 0.01329
# 5      0.12012 ± 0.02391      0.13378 ± 0.03388
# 6   63.11733 ± 108.37608  141.62064 ± 270.98067
# 7      4.22769 ± 1.12775      3.10515 ± 0.71466
# 8      0.05958 ± 0.02978      0.03214 ± 0.01481
# 9      0.06520 ± 0.01998      0.11111 ± 0.02899
# 10   12.42335 ± 18.43992    43.74588 ± 92.01504
# 11     2.45583 ± 0.86653      2.25129 ± 0.68579
# 12     0.02010 ± 0.01465      0.01689 ± 0.01035

# %%
adjusted_train_df.to_csv('/content/drive/MyDrive/BSP Paper Implementation/CSVs/Final Report/3EMD(0NaN)_train.csv', index=False)
adjusted_test_df.to_csv('/content/drive/MyDrive/BSP Paper Implementation/CSVs/Final Report/3EMD(0NaN)_test.csv', index=False)
